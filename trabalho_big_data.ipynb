# %% [markdown]
# <a href="https://colab.research.google.com/github/joaovictor-1/collab/blob/main/trabalho_big_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comandos para realização do trabalho da matéria de Big Data com uso da biblioteca PySpark.
#
# Este notebook foi projetado para guiar os alunos na realização das práticas de Big Data utilizando PySpark. Certifique-se de seguir cada etapa cuidadosamente para garantir a correta execução das atividades.
#
# Seu trabalho começará na célula 5. Execute as 4 primeiras células para iniciar a atividade.
#
# ## <font color=red>Observação importante:</font>
#
# <font color=yellow>Trabalho realizado com uso da biblioteca pandas não será aceito!</font>

# %% [markdown]
# ## Upload do arquivo `imdb-reviews-pt-br.csv` para dentro do Google Colab
#
# Aqui, você fará o download do dataset necessário para as atividades. Certifique-se de que o arquivo foi descompactado corretamente antes de prosseguir.

# %%
# !wget https://raw.githubusercontent.com/N-CPUninter/Big_Data/main/data/imdb-reviews-pt-br.zip -O imdb-reviews-pt-br.zip
# !unzip imdb-reviews-pt-br.zip
# !rm imdb-reviews-pt-br.zip
# Out:
# --2024-12-07 22:58:56--  https://raw.githubusercontent.com/N-CPUninter/Big_Data/main/data/imdb-reviews-pt-br.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49549692 (47M) [application/zip]
# Saving to: ‘imdb-reviews-pt-br.zip’
#
# imdb-reviews-pt-br. 100%[===================>]  47.25M   197MB/s    in 0.2s
#
# 2024-12-07 22:58:57 (197 MB/s) - ‘imdb-reviews-pt-br.zip’ saved [49549692/49549692]
#
# Archive:  imdb-reviews-pt-br.zip
#   inflating: imdb-reviews-pt-br.csv

# %% [markdown]
# ## Instalação manual das dependências para uso do pyspark no Google Colab
#
# Esta etapa garante que todas as bibliotecas necessárias para o PySpark sejam instaladas no Google Colab.

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# ## Importar, instanciar e criar a SparkSession
#
# A SparkSession é o ponto de entrada para usar o PySpark. Certifique-se de configurar corretamente o nome do aplicativo e o master.

# %%
from pyspark.sql import SparkSession

appName = "PySpark Trabalho de Big Data"
master = "local"

spark = SparkSession.builder.appName(appName).master(master).getOrCreate()

# %% [markdown]
# ## Criar spark dataframe do CSV utilizando o método read.csv do spark
#
# Não altere este código e use o dataframe imdb_df criado aqui em todo o seu trabalho. A criação de um dataframe diferente deste poderá causar erros na coluna sentiment e isso refletirá em erros de resposta das questões.

# %%
imdb_df = spark.read.csv('imdb-reviews-pt-br.csv',
                         header=True,
                         quote="\"",
                         escape="\"",
                         encoding="UTF-8")

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("CalculatingNegativeSentiments").getOrCreate()

# %%
negative_df = df.filter(df.sentiment == "neg")

# %%
total_sum = negative_df.selectExpr("sum(id)").collect()[0][0]

# %%
print("João Victor, RU: 4538676, coonsegui chegar no resultado da soma dos 'id' dos filmes classificados como negativos em:", total_sum)
# Out:
# João Victor, RU: 4538676, coonsegui chegar no resultado da soma dos 'id' dos filmes classificados como negativos em: 247015948

# %%
def map_sentiment_id(row):
    sentiment = row.sentiment
    id_value = int(row.id)
    return (sentiment, id_value)

# %%
spark = SparkSession.builder.appName("MapSentimentId").getOrCreate()

# %%
df = spark.read.csv("/content/imdb-reviews-pt-br.csv", header=True, inferSchema=True)

# %%
sentiment_id_rdd = df.rdd.map(map_sentiment_id)

# %%
print(sentiment_id_rdd.take(10))
# Out:
# [('neg', 1), ('neg', 2), (' exceto Paxton e o sem-teto e todos recebem o que merecem. Os dois únicos negros que podem atuar são o sem-teto e o viciado', 3), ('neg', 4), ('neg', 5), (' excuse me', 6), ('neg', 7), (' forcedly so', 8), (' and more talk. Youll get to see the less than stellar cast of three as they talk on the bus', 9), ('neg', 10)]

# %%
print("Resultado do mapeamento:")
print("João Victor RU:4538676")
for result in sentiment_id_rdd.take(10):
    print("Sentiment:", result[0], "ID:", result[1])
# Out:
# Resultado do mapeamento:
# João Victor RU:4538676
# Sentiment: neg ID: 1
# Sentiment: neg ID: 2
# Sentiment:  exceto Paxton e o sem-teto e todos recebem o que merecem. Os dois únicos negros que podem atuar são o sem-teto e o viciado ID: 3
# Sentiment: neg ID: 4
# Sentiment: neg ID: 5
# Sentiment:  excuse me ID: 6
# Sentiment: neg ID: 7
# Sentiment:  forcedly so ID: 8
# Sentiment:  and more talk. Youll get to see the less than stellar cast of three as they talk on the bus ID: 9
# Sentiment: neg ID: 10

# %% [markdown]
# # Questão 1
#
# Nesta questão, você irá calcular a soma dos IDs para entradas onde o sentimento ('sentiment') é 'neg'.
#
# ### Objetivo:
# - Usar a coluna 'sentiment' como chave e somar os valores da coluna 'id'.

# %% [markdown]
# ## Criar funções de MAP:
# - Criar função para mapear o "sentiment" como chave e o "id" como valor do tipo inteiro
#
# A função map irá transformar cada linha do dataframe em uma **tupla** (chave-valor), onde:
# - Chave: coluna 'sentiment'
# - Valor: coluna 'id' convertida para inteiro.

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("WordCount").getOrCreate()

# %%
df = spark.read.csv("/content/imdb-reviews-pt-br.csv", header=True, inferSchema=True)

# %%
negative_df = df.filter(df.sentiment == "neg")

# %%
def map_function(row):
    text = row["text_pt"]
    words = text.split()
    return [(word, 1) for word in words]

# %% [markdown]
# ## Cria funções de REDUCE:
#
# - Criar função de reduce para somar os IDs por "sentiment".
#
# A função reduce irá somar os valores dos IDs agrupados por chave ('sentiment').

# %%
def reduce_function(count1, count2):
    return count1 + count2

# %% [markdown]
# ## Aplicação do map/reduce e visualização do resultado
#
# Aqui, você aplicará as funções de map e reduce ao dataframe Spark para calcular os resultados. Não se esqueça de usar o método `.collect()` para visualizar os resultados.

# %%
word_counts = negative_df.rdd.flatMap(map_function).reduceByKey(reduce_function)

# %%
#testar contagem
result = word_counts.collect()
for word, count in result:
    print(f"Palavra: {word}, Contagem: {count}")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Palavra: tinha?, Contagem: 1
# Palavra: 38?, Contagem: 1
# Palavra: trabalhistas, Contagem: 1
# Palavra: PESSOAS., Contagem: 1
# Palavra: almoçar., Contagem: 1
# Palavra: Benigni., Contagem: 1
# Palavra: Roger,, Contagem: 1
# Palavra: UM,, Contagem: 1
# Palavra: anormais., Contagem: 1
# Palavra: um.Caso, Contagem: 1
# Palavra: precárias,, Contagem: 1
# Palavra: estrangeiros.Roberto,, Contagem: 1
# Palavra: Ebert;, Contagem: 1
# Palavra: profusivamente, Contagem: 1
# Palavra: Eberts., Contagem: 1
# Palavra: Torrences., Contagem: 1
# Palavra: Wendy., Contagem: 1
# Palavra: pontiagudas,, Contagem: 1
# Palavra: droney.2., Contagem: 1
# Palavra: excluídas,, Contagem: 1
# Palavra: incorretamente., Contagem: 1
# Palavra: hedge,, Contagem: 1
# Palavra: malho, Contagem: 2
# Palavra: roque,, Contagem: 1
# Palavra: irritado.3., Contagem: 1
# Palavra: Halorann, Contagem: 1
# Palavra: Overlook, Contagem: 1
# Palavra: Hallorann, Contagem: 1
# Palavra: roque., Contagem: 1
# Palavra: roque, Contagem: 1
# Palavra: Kubrik, Contagem: 1
# Palavra: hedge., Contagem: 1
# Palavra: ridículas.1, Contagem: 1
# Palavra: italianos:, Contagem: 1
# Palavra: Cosmatos, Contagem: 1
# Palavra: ""arte""., Contagem: 1
# Palavra: LOURO, Contagem: 1
# Palavra: PAPELÃO, Contagem: 1
# Palavra: HIS, Contagem: 1
# Palavra: GIRL, Contagem: 1
# Palavra: PHILADELPHIA, Contagem: 1
# Palavra: STORY., Contagem: 1
# Palavra: indomável, Contagem: 1
# Palavra: proto-feministas, Contagem: 1
# Palavra: CARDBOARD, Contagem: 1
# Palavra: gigolô., Contagem: 1
# Palavra: inflexões, Contagem: 1
# Palavra: Consuelo, Contagem: 1
# Palavra: Craydon, Contagem: 1
# Palavra: papéis;, Contagem: 1
# Palavra: Miniver, Contagem: 1
# Palavra: mega-hits, Contagem: 1
# Palavra: MRS., Contagem: 1
# Palavra: MINIVER, Contagem: 1
# Palavra: exterminar,, Contagem: 1
# Palavra: Gilberts., Contagem: 1
# Palavra: convolve, Contagem: 2
# Palavra: ilustração, Contagem: 2
# Palavra: ""Boomerang"", Contagem: 2
# Palavra: ""Extremidades"".", Contagem: 2
# Palavra: laconicamente, Contagem: 1
# Palavra: Caffari,, Contagem: 1
# Palavra: Nintendos., Contagem: 1
# Palavra: encapuzadas., Contagem: 1
# Palavra: Artigot, Contagem: 2
# Palavra: Semperes, Contagem: 1
# Palavra: relaxe., Contagem: 1
# Palavra: García, Contagem: 1
# Palavra: Morcillos,, Contagem: 1
# Palavra: mistura-se, Contagem: 1
# Palavra: Vítor, Contagem: 1
# Palavra: Dannys, Contagem: 1
# Palavra: Wendy?, Contagem: 1
# Palavra: assustava., Contagem: 1
# Palavra: Gaffari, Contagem: 1
# Palavra: Gaffari., Contagem: 1
# Palavra: hospitaleira, Contagem: 1
# Palavra: Hansel, Contagem: 1
# Palavra: Gretel,, Contagem: 1
# Palavra: Eurohorror,, Contagem: 1
# Palavra: Pirineus?, Contagem: 1
# Palavra: ocultas., Contagem: 1
# Palavra: verdejantes, Contagem: 1
# Palavra: comandam., Contagem: 1
# Palavra: archive.org., Contagem: 1
# Palavra: MOUNTAIN, Contagem: 1
# Palavra: las, Contagem: 1
# Palavra: brujas, Contagem: 1
# Palavra: set.The, Contagem: 1
# Palavra: exasperada, Contagem: 1
# Palavra: malcriada., Contagem: 1
# Palavra: estupendo, Contagem: 1
# Palavra: pretas., Contagem: 1
# Palavra: investigam,, Contagem: 1
# Palavra: saem,, Contagem: 3
# Palavra: sonâmbulo,, Contagem: 1
# Palavra: guarda-roupas, Contagem: 1
# Palavra: consistentes,, Contagem: 1
# Palavra: deixa-a, Contagem: 1
# Palavra: desprotegida, Contagem: 2
# Palavra: retirada,, Contagem: 1
# Palavra: atmosféricas,, Contagem: 1
# Palavra: noturnos., Contagem: 2
# Palavra: assustador;, Contagem: 1
# Palavra: enervantes., Contagem: 1
# Palavra: Dares, Contagem: 2
# Palavra: Wins;, Contagem: 1
# Palavra: Option,, Contagem: 1
# Palavra: Sharp., Contagem: 1
# Palavra: excitações, Contagem: 1
# Palavra: concretizem,, Contagem: 1
# Palavra: esforço.SAS, Contagem: 1
# Palavra: Skellen, Contagem: 2
# Palavra: Frankies, Contagem: 2
# Palavra: sitiam, Contagem: 1
# Palavra: juntarão, Contagem: 1
# Palavra: Frankie,, Contagem: 1
# Palavra: embaixada,, Contagem: 1
# Palavra: SAS., Contagem: 1
# Palavra: Assalto, Contagem: 1
# Palavra: arquebucos, Contagem: 1
# Palavra: instigando, Contagem: 1
# Palavra: absurdity., Contagem: 1
# Palavra: ex-membro, Contagem: 1
# Palavra: Professionals,, Contagem: 1
# Palavra: soldado-da-sorte, Contagem: 1
# Palavra: Piedade,, Contagem: 1
# Palavra: versátil,, Contagem: 1
# Palavra: adiantados., Contagem: 1
# Palavra: semi-realista,, Contagem: 1
# Palavra: é.Além, Contagem: 1
# Palavra: surgindo,, Contagem: 1
# Palavra: artística!, Contagem: 1
# Palavra: Greta,, Contagem: 1
# Palavra: egos., Contagem: 1
# Palavra: sela., Contagem: 1
# Palavra: Johns., Contagem: 1
# Palavra: quinhão., Contagem: 1
# Palavra: medianas,, Contagem: 1
# Palavra: verem., Contagem: 1
# Palavra: CAMILLE, Contagem: 2
# Palavra: PanavisionSound:, Contagem: 1
# Palavra: MonoEnquanto, Contagem: 1
# Palavra: Castelnuovo,, Contagem: 1
# Palavra: libertino, Contagem: 1
# Palavra: Daniele, Contagem: 1
# Palavra: Gaubert,, Contagem: 1
# Palavra: Castelnuovos,, Contagem: 1
# Palavra: Massimo, Contagem: 1
# Palavra: Serato,, Contagem: 1
# Palavra: Aux, Contagem: 1
# Palavra: Camélias, Contagem: 1
# Palavra: DeForrest,, Contagem: 1
# Palavra: Radley, Contagem: 1
# Palavra: Metzger, Contagem: 2
# Palavra: Sarno, Contagem: 1
# Palavra: redefinição, Contagem: 1
# Palavra: dolce, Contagem: 1
# Palavra: vita, Contagem: 1
# Palavra: Metzgers, Contagem: 1
# Palavra: nota-se, Contagem: 1
# Palavra: reflexivas,, Contagem: 1
# Palavra: Castelnuovo, Contagem: 1
# Palavra: Gaubert, Contagem: 1
# Palavra: pós-sincronização., Contagem: 1
# Palavra: especificado,, Contagem: 1
# Palavra: Sabbatinis, Contagem: 1
# Palavra: firmeza,, Contagem: 1
# Palavra: Piccionis, Contagem: 1
# Palavra: wah-wah, Contagem: 1
# Palavra: adquirido,, Contagem: 1
# Palavra: LICKERISH, Contagem: 1
# Palavra: QUARTET, Contagem: 1
# Palavra: Matlins, Contagem: 2
# Palavra: namoraram, Contagem: 1
# Palavra: Doce., Contagem: 1
# Palavra: Retratou, Contagem: 1
# Palavra: surdas, Contagem: 2
# Palavra: cautelosas, Contagem: 1
# Palavra: zangadas,, Contagem: 1
# Palavra: Matlin., Contagem: 1
# Palavra: Inferior, Contagem: 1
# Palavra: Digno,, Contagem: 1
# Palavra: Morto!, Contagem: 1
# Palavra: "MORTOS, Contagem: 1
# Palavra: MARIDOS, Contagem: 1
# Palavra: compromete, Contagem: 2
# Palavra: Elson., Contagem: 1
# Palavra: Springer?, Contagem: 1
# Palavra: Elson, Contagem: 1
# Palavra: ""cuidar, Contagem: 1
# Palavra: falando""", Contagem: 1
# Palavra: meias.Este, Contagem: 1
# Palavra: dirijo, Contagem: 1
# Palavra: Voltas, Contagem: 1
# Palavra: cozinhas., Contagem: 1
# Palavra: desapareça., Contagem: 1
# Palavra: ex-soldado, Contagem: 1
# Palavra: ex-condenado., Contagem: 1
# Palavra: metódico,, Contagem: 1
# Palavra: inflexões., Contagem: 1
# Palavra: balky, Contagem: 1
# Palavra: volumosas,, Contagem: 1
# Palavra: vacilante, Contagem: 2
# Palavra: interpolação, Contagem: 1
# Palavra: antiautoritária, Contagem: 1
# Palavra: moralistas,, Contagem: 2
# Palavra: saudações, Contagem: 1
# Palavra: Deliverance,, Contagem: 1
# Palavra: Promessas, Contagem: 1
# Palavra: Orientais, Contagem: 1
# Palavra: Runner., Contagem: 1
# Palavra: herdeira;, Contagem: 1
# Palavra: médiuns, Contagem: 1
# Palavra: Sólida, Contagem: 1
# Palavra: chiller., Contagem: 1
# Palavra: sinistra., Contagem: 1
# Palavra: deslizantes,, Contagem: 1
# Palavra: trovões, Contagem: 1
# Palavra: relâmpagos, Contagem: 1
# Palavra: envenenados., Contagem: 1
# Palavra: melodramatics, Contagem: 1
# Palavra: gás., Contagem: 1
# Palavra: Kyser., Contagem: 1
# Palavra: Kyer,, Contagem: 1
# Palavra: músicos., Contagem: 1
# Palavra: envenenados, Contagem: 1
# Palavra: emoldurados, Contagem: 1
# Palavra: swami, Contagem: 1
# Palavra: risonhas, Contagem: 1
# Palavra: McHugh, Contagem: 1
# Palavra: gabar,, Contagem: 1
# Palavra: Postlesumthing, Contagem: 1
# Palavra: Ficaria, Contagem: 1
# Palavra: 2a., Contagem: 1
# Palavra: semi-rural, Contagem: 1
# Palavra: parece-se., Contagem: 1
# Palavra: metropolitana., Contagem: 1
# Palavra: secos., Contagem: 1
# Palavra: tagarelam,, Contagem: 1
# Palavra: corais., Contagem: 1
# Palavra: Pico,, Contagem: 1
# Palavra: caminhadas,, Contagem: 1
# Palavra: estendiam, Contagem: 1
# Palavra: Gales., Contagem: 2
# Palavra: Gwynedd,, Contagem: 1
# Palavra: ermo., Contagem: 1
# Palavra: apaixonar,, Contagem: 1
# Palavra: cobiça,, Contagem: 1
# Palavra: famílias;, Contagem: 1
# Palavra: Sheffielders, Contagem: 1
# Palavra: desviado., Contagem: 1
# Palavra: gigantesca!, Contagem: 1
# Palavra: fruta, Contagem: 1
# Palavra: tendemos, Contagem: 1
# Palavra: horário!, Contagem: 1
# Palavra: pintarem., Contagem: 1
# Palavra: resmungadas., Contagem: 1
# Palavra: prequels,, Contagem: 1
# Palavra: agrupada, Contagem: 1
# Palavra: prequels, Contagem: 1
# Palavra: Sith, Contagem: 1
# Palavra: prequel., Contagem: 2
# Palavra: notou., Contagem: 1
# Palavra: venerada, Contagem: 1
# Palavra: 12:01,, Contagem: 1
# Palavra: resmungaram, Contagem: 1
# Palavra: exemplo!, Contagem: 1
# Palavra: Halloran!, Contagem: 1
# Palavra: Jedi,, Contagem: 1
# Palavra: Menace,, Contagem: 1
# Palavra: Clowns, Contagem: 1
# Palavra: Sith,, Contagem: 1
# Palavra: Annakin, Contagem: 2
# Palavra: Vader?, Contagem: 1
# Palavra: Moron,, Contagem: 1
# Palavra: empilhou, Contagem: 1
# Palavra: spoilers?, Contagem: 1
# Palavra: Countoo, Contagem: 1
# Palavra: verbais, Contagem: 2
# Palavra: Yogi, Contagem: 1
# Palavra: Berra., Contagem: 1
# Palavra: C3P0., Contagem: 1
# Palavra: pulgas., Contagem: 1
# Palavra: bh, Contagem: 1
# Palavra: Amma-Lamma-Ding-Dong., Contagem: 1
# Palavra: contara, Contagem: 1
# Palavra: público:, Contagem: 1
# Palavra: Detectives, Contagem: 3
# Palavra: insinuado,, Contagem: 1
# Palavra: Neils, Contagem: 1
# Palavra: -Questions?, Contagem: 1
# Palavra: -Reprimir, Contagem: 1
# Palavra: Fidelity,, Contagem: 1
# Palavra: vitoriosas., Contagem: 1
# Palavra: apoderou, Contagem: 1
# Palavra: FILMES,, Contagem: 1
# Palavra: não-matemático!, Contagem: 1
# Palavra: romântica?, Contagem: 1
# Palavra: tampouco., Contagem: 1
# Palavra: occassionaly, Contagem: 1
# Palavra: gorythe, Contagem: 1
# Palavra: thoughno, Contagem: 1
# Palavra: legal;, Contagem: 1
# Palavra: PERIL!, Contagem: 1
# Palavra: assustadoras?, Contagem: 1
# Palavra: dubladas,, Contagem: 1
# Palavra: ther, Contagem: 1
# Palavra: joia?, Contagem: 1
# Palavra: Lesmas, Contagem: 1
# Palavra: Brady!, Contagem: 1
# Palavra: derrubar,, Contagem: 1
# Palavra: MIKE, Contagem: 1
# Palavra: BRADY!, Contagem: 1
# Palavra: YMCA,, Contagem: 1
# Palavra: Blob,, Contagem: 2
# Palavra: Hutson., Contagem: 1
# Palavra: autoridades.Apenas,, Contagem: 1
# Palavra: bisbilhotar,, Contagem: 1
# Palavra: Breeding, Contagem: 1
# Palavra: ground!, Contagem: 1
# Palavra: autoajuda,, Contagem: 1
# Palavra: Linette., Contagem: 1
# Palavra: simpáticas,, Contagem: 1
# Palavra: holístico, Contagem: 1
# Palavra: Parts., Contagem: 1
# Palavra: Rodney., Contagem: 2
# Palavra: tubo,, Contagem: 1
# Palavra: Candyshack, Contagem: 1
# Palavra: Ladybugs, Contagem: 1
# Palavra: Joaninhas,, Contagem: 1
# Palavra: Wives,, Contagem: 1
# Palavra: gerida, Contagem: 1
# Palavra: Amish,, Contagem: 1
# Palavra: esposas., Contagem: 1
# Palavra: Dice, Contagem: 1
# Palavra: perplexo,, Contagem: 2
# Palavra: acreditar:, Contagem: 1
# Palavra: dinamarquesas, Contagem: 1
# Palavra: dinamarquesa,, Contagem: 1
# Palavra: Chrissy,, Contagem: 1
# Palavra: formulada., Contagem: 1
# Palavra: Tamahoris, Contagem: 1
# Palavra: inspirarão,, Contagem: 1
# Palavra: entreterem, Contagem: 1
# Palavra: Mencionar, Contagem: 1
# Palavra: bem-dotada,, Contagem: 1
# Palavra: 73,, Contagem: 1
# Palavra: Hidden, Contagem: 1
# Palavra: revitalização, Contagem: 1
# Palavra: crass., Contagem: 1
# Palavra: Cheng., Contagem: 1
# Palavra: Ching, Contagem: 1
# Palavra: super-inteligente, Contagem: 1
# Palavra: Lin., Contagem: 1
# Palavra: antemão., Contagem: 1
# Palavra: repercussões, Contagem: 1
# Palavra: flamengo, Contagem: 1
# Palavra: marroquino, Contagem: 2
# Palavra: Loach,, Contagem: 1
# Palavra: Antuérpia., Contagem: 1
# Palavra: Bloco, Contagem: 1
# Palavra: Flamengo, Contagem: 1
# Palavra: culturas., Contagem: 1
# Palavra: divisórias, Contagem: 1
# Palavra: 2000Dries, Contagem: 1
# Palavra: Dongen, Contagem: 1
# Palavra: Analisando, Contagem: 1
# Palavra: Bimbo, Contagem: 1
# Palavra: Temível, Contagem: 1
# Palavra: Tribal,, Contagem: 1
# Palavra: Shower, Contagem: 1
# Palavra: Chuveiro, Contagem: 1
# Palavra: Súcubo,, Contagem: 1
# Palavra: Necronomicon, Contagem: 1
# Palavra: Geträumte, Contagem: 1
# Palavra: Sünden,, Contagem: 1
# Palavra: coma.Jess, Contagem: 1
# Palavra: alucinógeno,, Contagem: 1
# Palavra: 180+?, Contagem: 1
# Palavra: Deixá-lo, Contagem: 1
# Palavra: GOLDEN:, Contagem: 1
# Palavra: SAVITCH, Contagem: 1
# Palavra: JESSICARelação, Contagem: 1
# Palavra: StereoBland,, Contagem: 1
# Palavra: telejornal, Contagem: 1
# Palavra: correia, Contagem: 1
# Palavra: suckiness, Contagem: 1
# Palavra: excessivas, Contagem: 1
# Palavra: Concert, Contagem: 1
# Palavra: lançados;, Contagem: 1
# Palavra: decomponha, Contagem: 1
# Palavra: Barker!, Contagem: 1
# Palavra: Interessante., Contagem: 1
# Palavra: reasonmovies, Contagem: 1
# Palavra: Base., Contagem: 1
# Palavra: Dirigir,, Contagem: 1
# Palavra: Patriota,, Contagem: 1
# Palavra: Santuário, Contagem: 1
# Palavra: Misbegotten, Contagem: 1
# Palavra: 1e, Contagem: 1
# Palavra: Fio, Contagem: 1
# Palavra: Mancuso., Contagem: 1
# Palavra: Succubus, Contagem: 2
# Palavra: saqueando;, Contagem: 1
# Palavra: curta-metragem;, Contagem: 1
# Palavra: surreal;, Contagem: 1
# Palavra: Hoax, Contagem: 1
# Palavra: Rajasthan., Contagem: 2
# Palavra: indianos;, Contagem: 1
# Palavra: Jaipur., Contagem: 1
# Palavra: Amer, Contagem: 1
# Palavra: Jaipur,, Contagem: 1
# Palavra: Bonus, Contagem: 1
# Palavra: Cabul, Contagem: 1
# Palavra: folclórica, Contagem: 2
# Palavra: Afgani., Contagem: 1
# Palavra: Rajastão., Contagem: 1
# Palavra: extensivamente?, Contagem: 1
# Palavra: enviá-los, Contagem: 1
# Palavra: espancá-los, Contagem: 1
# Palavra: Reynaud, Contagem: 1
# Palavra: SM, Contagem: 1
# Palavra: Reynauds, Contagem: 1
# Palavra: maneater, Contagem: 1
# Palavra: Vampiras,, Contagem: 1
# Palavra: Orloff, Contagem: 1
# Palavra: Feminino., Contagem: 1
# Palavra: lars, Contagem: 1
# Palavra: bisleriana,, Contagem: 1
# Palavra: hahah, Contagem: 1
# Palavra: Joeseph, Contagem: 1
# Palavra: Osama., Contagem: 1
# Palavra: factualwhile, Contagem: 1
# Palavra: mundo.I, Contagem: 1
# Palavra: alertou, Contagem: 2
# Palavra: ""Documentário"", Contagem: 1
# Palavra: reais.", Contagem: 1
# Palavra: DinoCrap,, Contagem: 1
# Palavra: roubei, Contagem: 1
# Palavra: rabo., Contagem: 1
# Palavra: AHAHAHAHAHHAHAHAHAHAHAHAHAHAHHAHAHAHAHAHAHAH, Contagem: 1
# Palavra: !!!!!!!!!!!!!!!!!!!, Contagem: 1
# Palavra: homoeric?, Contagem: 1
# Palavra: alta;, Contagem: 2
# Palavra: Its-its, Contagem: 1
# Palavra: DINOCRAP!, Contagem: 1
# Palavra: não-zumbi,, Contagem: 1
# Palavra: Dinocroc, Contagem: 3
# Palavra: Longenecker, Contagem: 1
# Palavra: carnudo,, Contagem: 1
# Palavra: komodocoughs., Contagem: 1
# Palavra: 3/6, Contagem: 1
# Palavra: McGuires, Contagem: 2
# Palavra: 2,6, Contagem: 1
# Palavra: super-crocodilos, Contagem: 1
# Palavra: E.V.I.L., Contagem: 1
# Palavra: dinocroco, Contagem: 1
# Palavra: DUH, Contagem: 1
# Palavra: dinocroc, Contagem: 3
# Palavra: Dinocroc., Contagem: 1
# Palavra: pendurá-lo, Contagem: 1
# Palavra: chutando-o, Contagem: 1
# Palavra: colasse, Contagem: 1
# Palavra: influenciaria, Contagem: 1
# Palavra: B-grade, Contagem: 2
# Palavra: sentariam, Contagem: 1
# Palavra: risos?, Contagem: 1
# Palavra: níveis;, Contagem: 1
# Palavra: complicada.Plan, Contagem: 1
# Palavra: comédia.Uma, Contagem: 1
# Palavra: saccharine, Contagem: 1
# Palavra: crap.there, Contagem: 1
# Palavra: point, Contagem: 1
# Palavra: ciência-run-amok, Contagem: 1
# Palavra: colírio., Contagem: 1
# Palavra: piñata., Contagem: 1
# Palavra: Spoilerwarning, Contagem: 1
# Palavra: jaula,, Contagem: 1
# Palavra: dourado, Contagem: 2
# Palavra: demitiram, Contagem: 1
# Palavra: participei,, Contagem: 1
# Palavra: doeu., Contagem: 1
# Palavra: Robards, Contagem: 3
# Palavra: Pryce, Contagem: 3
# Palavra: gostem., Contagem: 1
# Palavra: Bradbury., Contagem: 2
# Palavra: Fahrenheit, Contagem: 1
# Palavra: 451, Contagem: 1
# Palavra: Dandelion, Contagem: 1
# Palavra: Wine., Contagem: 1
# Palavra: Jonathn, Contagem: 1
# Palavra: Pryce., Contagem: 1
# Palavra: PAM, Contagem: 1
# Palavra: GRIER!, Contagem: 1
# Palavra: estupidificado., Contagem: 1
# Palavra: abordada., Contagem: 1
# Palavra: Halloway, Contagem: 1
# Palavra: Poeira, Contagem: 1
# Palavra: carrossel,, Contagem: 1
# Palavra: varetas,, Contagem: 1
# Palavra: bashes,, Contagem: 1
# Palavra: Quênia, Contagem: 2
# Palavra: brincalhões,, Contagem: 1
# Palavra: Sharat.O, Contagem: 1
# Palavra: prolongadoRajiv, Contagem: 1
# Palavra: Camera-work, Contagem: 1
# Palavra: bomSunny, Contagem: 1
# Palavra: Chunky, Contagem: 1
# Palavra: TRIDEV, Contagem: 1
# Palavra: Chibas., Contagem: 1
# Palavra: americanizada,, Contagem: 1
# Palavra: Chibas, Contagem: 1
# Palavra: Warriors., Contagem: 1
# Palavra: traseiros,, Contagem: 1
# Palavra: meia-boca, Contagem: 1
# Palavra: EXCETO, Contagem: 1
# Palavra: japoneses!, Contagem: 1
# Palavra: Chiba,, Contagem: 1
# Palavra: detê-los,, Contagem: 1
# Palavra: Chiba., Contagem: 1
# Palavra: Karatê, Contagem: 1
# Palavra: intenções?, Contagem: 1
# Palavra: mal-coreografadas, Contagem: 1
# Palavra: semi-assistível, Contagem: 1
# Palavra: porcas,, Contagem: 1
# Palavra: socando-o, Contagem: 1
# Palavra: Terríveis, Contagem: 1
# Palavra: fratura, Contagem: 1
# Palavra: composta., Contagem: 1
# Palavra: dublam, Contagem: 1
# Palavra: ​​postas, Contagem: 1
# Palavra: baleeira., Contagem: 1
# Palavra: chato.Em, Contagem: 1
# Palavra: aguentar., Contagem: 2
# Palavra: aumentam., Contagem: 1
# Palavra: republicano,, Contagem: 1
# Palavra: cargo., Contagem: 2
# Palavra: Colbert., Contagem: 1
# Palavra: CC, Contagem: 1
# Palavra: "Honestamente,, Contagem: 1
# Palavra: ríspidas,, Contagem: 1
# Palavra: Macromedias, Contagem: 1
# Palavra: não-engraçados., Contagem: 1
# Palavra: ""Lil, Contagem: 1
# Palavra: Bush"", Contagem: 1
# Palavra: ""Thats, Contagem: 1
# Palavra: Bush""., Contagem: 1
# Palavra: agradecer.", Contagem: 1
# Palavra: resmunga, Contagem: 1
# Palavra: Condoleeza, Contagem: 1
# Palavra: Rumsfeld., Contagem: 1
# Palavra: democráticos, Contagem: 1
# Palavra: coerentes,, Contagem: 1
# Palavra: afunde., Contagem: 1
# Palavra: c-span, Contagem: 1
# Palavra: c-span.I, Contagem: 1
# Palavra: abri, Contagem: 2
# Palavra: engraçadas.Comédia, Contagem: 1
# Palavra: tirado,, Contagem: 2
# Palavra: insondáveis, Contagem: 1
# Palavra: ​​tho., Contagem: 1
# Palavra: lago?, Contagem: 2
# Palavra: abanando,, Contagem: 1
# Palavra: casacos?, Contagem: 1
# Palavra: publicistas, Contagem: 1
# Palavra: disfarçados!, Contagem: 1
# Palavra: ameaçada., Contagem: 1
# Palavra: ""sulista"", Contagem: 1
# Palavra: Ambers, Contagem: 1
# Palavra: Rohm,, Contagem: 1
# Palavra: esforçar,, Contagem: 1
# Palavra: Natwick,, Contagem: 1
# Palavra: bem.Ele, Contagem: 1
# Palavra: bondoso, Contagem: 1
# Palavra: Rohm, Contagem: 2
# Palavra: Arlington., Contagem: 1
# Palavra: Âmbar, Contagem: 1
# Palavra: inconsolável, Contagem: 1
# Palavra: idêntica., Contagem: 1
# Palavra: ADAs, Contagem: 1
# Palavra: sequestrada;, Contagem: 1
# Palavra: distraia, Contagem: 1
# Palavra: Rohms, Contagem: 1
# Palavra: espessa, Contagem: 1
# Palavra: Alert, Contagem: 1
# Palavra: Timmons, Contagem: 2
# Palavra: prejudicá-la., Contagem: 1
# Palavra: levantou-a, Contagem: 1
# Palavra: prejudicá-la, Contagem: 1
# Palavra: paisagista., Contagem: 1
# Palavra: consideravam, Contagem: 1
# Palavra: postei, Contagem: 2
# Palavra: Primal, Contagem: 2
# Palavra: Winfrey., Contagem: 1
# Palavra: Halston,, Contagem: 1
# Palavra: Burnette., Contagem: 1
# Palavra: CARNOSAUR., Contagem: 1
# Palavra: FANNN-TASTIC!, Contagem: 1
# Palavra: Wilkes, Contagem: 1
# Palavra: Misery, Contagem: 1
# Palavra: nevados., Contagem: 1
# Palavra: Berry., Contagem: 1
# Palavra: Horizons, Contagem: 1
# Palavra: C3, Contagem: 1
# Palavra: Good., Contagem: 1
# Palavra: "Primal, Contagem: 1
# Palavra: surpreendidos, Contagem: 1
# Palavra: répteis.Você, Contagem: 1
# Palavra: Pesadelo."", Contagem: 1
# Palavra: Currie", Contagem: 1
# Palavra: Rance, Contagem: 2
# Palavra: encurvando, Contagem: 1
# Palavra: gêmeo,, Contagem: 1
# Palavra: Proctor, Contagem: 1
# Palavra: dançar..vimos, Contagem: 1
# Palavra: 30min, Contagem: 1
# Palavra: 30min,, Contagem: 1
# Palavra: herbal,, Contagem: 1
# Palavra: carnosours, Contagem: 1
# Palavra: alugando., Contagem: 1
# Palavra: Sheedys,, Contagem: 1
# Palavra: macilenta, Contagem: 1
# Palavra: brilhantemente., Contagem: 1
# Palavra: antiquados,, Contagem: 1
# Palavra: Kellers, Contagem: 1
# Palavra: Tomanovich, Contagem: 1
# Palavra: indistinto., Contagem: 1
# Palavra: primárias, Contagem: 1
# Palavra: analisá-los., Contagem: 1
# Palavra: Polchak,, Contagem: 1
# Palavra: sobreviveria, Contagem: 1
# Palavra: amuados, Contagem: 1
# Palavra: porno., Contagem: 1
# Palavra: carnossauro., Contagem: 1
# Palavra: dinossauro!, Contagem: 1
# Palavra: Dinos, Contagem: 5
# Palavra: Dinos,, Contagem: 1
# Palavra: Rance,, Contagem: 2
# Palavra: velociraptor,, Contagem: 1
# Palavra: encontrado!, Contagem: 1
# Palavra: vier,, Contagem: 1
# Palavra: lavam, Contagem: 1
# Palavra: t-rex, Contagem: 3
# Palavra: Tristemente, Contagem: 1
# Palavra: loura, Contagem: 1
# Palavra: capturasse, Contagem: 2
# Palavra: Jesuíta, Contagem: 1
# Palavra: façanhas!, Contagem: 1
# Palavra: saíam., Contagem: 1
# Palavra: elite., Contagem: 1
# Palavra: freezers,, Contagem: 1
# Palavra: disquetes.Ill, Contagem: 1
# Palavra: 50-60, Contagem: 1
# Palavra: correram,, Contagem: 1
# Palavra: balançaram, Contagem: 1
# Palavra: moveram., Contagem: 1
# Palavra: moviam,, Contagem: 1
# Palavra: falsidade., Contagem: 1
# Palavra: carnossauros, Contagem: 1
# Palavra: this.Now, Contagem: 1
# Palavra: bc, Contagem: 1
# Palavra: animando, Contagem: 2
# Palavra: sério?""", Contagem: 1
# Palavra: raptores,, Contagem: 1
# Palavra: T-REX, Contagem: 1
# Palavra: mona, Contagem: 1
# Palavra: lisa, Contagem: 2
# Palavra: bb-bad, Contagem: 1
# Palavra: BORRACHA, Contagem: 1
# Palavra: OOPPS!, Contagem: 1
# Palavra: Budget, Contagem: 2
# Palavra: disso.Um, Contagem: 1
# Palavra: Lorry, Contagem: 1
# Palavra: Acredite-se, Contagem: 1
# Palavra: urânio,, Contagem: 2
# Palavra: Crack,, Contagem: 1
# Palavra: .KO,, Contagem: 1
# Palavra: 100?, Contagem: 1
# Palavra: IMDbA, Contagem: 1
# Palavra: Snobs, Contagem: 1
# Palavra: Valentine;, Contagem: 1
# Palavra: Cheirar, Contagem: 1
# Palavra: Friends.There, Contagem: 1
# Palavra: Rances, Contagem: 1
# Palavra: tremeluzir, Contagem: 1
# Palavra: Velociraptor, Contagem: 1
# Palavra: preempossível,, Contagem: 1
# Palavra: Jusassic, Contagem: 1
# Palavra: estrondoso., Contagem: 1
# Palavra: pirralha,, Contagem: 1
# Palavra: répteis,, Contagem: 2
# Palavra: Votar:, Contagem: 1
# Palavra: Berlin,, Contagem: 1
# Palavra: mando., Contagem: 1
# Palavra: quânticos, Contagem: 1
# Palavra: Berlim.Não, Contagem: 1
# Palavra: criancinhas., Contagem: 1
# Palavra: dunnit,, Contagem: 1
# Palavra: Spreading, Contagem: 1
# Palavra: esportiva., Contagem: 1
# Palavra: engate:, Contagem: 1
# Palavra: Det., Contagem: 1
# Palavra: Delongpre, Contagem: 1
# Palavra: Killer., Contagem: 1
# Palavra: Spree.Ok, Contagem: 1
# Palavra: Gault, Contagem: 1
# Palavra: McCamus, Contagem: 1
# Palavra: Contradição?, Contagem: 1
# Palavra: Yanno?, Contagem: 1
# Palavra: esses.Derek, Contagem: 1
# Palavra: Vanlint, Contagem: 1
# Palavra: Vanlints, Contagem: 1
# Palavra: acompanharia, Contagem: 1
# Palavra: decepcionante.Este, Contagem: 1
# Palavra: exaustivos, Contagem: 1
# Palavra: heh.Skip, Contagem: 1
# Palavra: Parecia-se, Contagem: 1
# Palavra: Shider, Contagem: 1
# Palavra: verão!, Contagem: 1
# Palavra: crus., Contagem: 2
# Palavra: Autoridade, Contagem: 1
# Palavra: tremidas, Contagem: 1
# Palavra: Prenúncio, Contagem: 1
# Palavra: Finalidade, Contagem: 1
# Palavra: Percebeu, Contagem: 1
# Palavra: suspense"", Contagem: 1
# Palavra: arrepender.", Contagem: 1
# Palavra: Auteil, Contagem: 1
# Palavra: Pasqal, Contagem: 1
# Palavra: Duquenne,, Contagem: 1
# Palavra: executivos,, Contagem: 1
# Palavra: Acenando, Contagem: 1
# Palavra: Landon, Contagem: 2
# Palavra: culminam, Contagem: 1
# Palavra: Lego-room,, Contagem: 1
# Palavra: supercomputadores., Contagem: 1
# Palavra: CALDEIRA., Contagem: 1
# Palavra: DEVOU, Contagem: 1
# Palavra: ADVOGADO., Contagem: 1
# Palavra: Conpsiracies, Contagem: 1
# Palavra: room, Contagem: 1
# Palavra: Antitruste, Contagem: 2
# Palavra: competitivo, Contagem: 1
# Palavra: informática., Contagem: 1
# Palavra: Pacientemente, Contagem: 1
# Palavra: Phillipe., Contagem: 1
# Palavra: nerds,, Contagem: 1
# Palavra: Causando, Contagem: 1
# Palavra: cruas,, Contagem: 1
# Palavra: antitruste, Contagem: 3
# Palavra: elementos-chave,, Contagem: 1
# Palavra: Net., Contagem: 1
# Palavra: Antirust,, Contagem: 1
# Palavra: percepção:, Contagem: 1
# Palavra: software., Contagem: 2
# Palavra: indústrias,, Contagem: 1
# Palavra: expandida, Contagem: 1
# Palavra: alérgico, Contagem: 2
# Palavra: Seeds,, Contagem: 1
# Palavra: ingerir, Contagem: 2
# Palavra: breadsticks, Contagem: 1
# Palavra: gergelim,, Contagem: 1
# Palavra: encapuzam, Contagem: 1
# Palavra: pãezinhos, Contagem: 1
# Palavra: Mac., Contagem: 1
# Palavra: padronizadas, Contagem: 1
# Palavra: reveladas,, Contagem: 1
# Palavra: Yee, Contagem: 1
# Palavra: Jee, Contagem: 1
# Palavra: Tso, Contagem: 1
# Palavra: moratória, Contagem: 1
# Palavra: Simple, Contagem: 2
# Palavra: continuei., Contagem: 1
# Palavra: N.U.V., Contagem: 1
# Palavra: jornalística, Contagem: 1
# Palavra: Hinckley, Contagem: 1
# Palavra: Winston,, Contagem: 2
# Palavra: Road., Contagem: 1
# Palavra: antitruste,, Contagem: 1
# Palavra: Anticlimatictic, Contagem: 1
# Palavra: Anti-, Contagem: 1
# Palavra: UHF, Contagem: 1
# Palavra: açoitando, Contagem: 1
# Palavra: spoilers.A, Contagem: 1
# Palavra: hacker,, Contagem: 1
# Palavra: nerd-fantasia-realidade, Contagem: 1
# Palavra: Bellamy, Contagem: 1
# Palavra: programadores, Contagem: 5
# Palavra: programadores., Contagem: 1
# Palavra: satélites, Contagem: 1
# Palavra: freq.,, Contagem: 1
# Palavra: Povos, Contagem: 1
# Palavra: impar, Contagem: 1
# Palavra: RELATED, Contagem: 1
# Palavra: acurada, Contagem: 1
# Palavra: Justiça, Contagem: 1
# Palavra: corp, Contagem: 1
# Palavra: diretamente;, Contagem: 1
# Palavra: indireto, Contagem: 1
# Palavra: nicotina,, Contagem: 1
# Palavra: poluição,, Contagem: 1
# Palavra: aditivos,, Contagem: 1
# Palavra: venenos,, Contagem: 1
# Palavra: Microsoft, Contagem: 2
# Palavra: McNealy,, Contagem: 1
# Palavra: SUN., Contagem: 1
# Palavra: McNealy, Contagem: 1
# Palavra: Microsystem,, Contagem: 1
# Palavra: Microsoft., Contagem: 2
# Palavra: SUN,, Contagem: 1
# Palavra: McNealy., Contagem: 1
# Palavra: blasfema., Contagem: 1
# Palavra: Aldolpho, Contagem: 3
# Palavra: Bealswho, Contagem: 1
# Palavra: financeiro., Contagem: 1
# Palavra: inicializar., Contagem: 1
# Palavra: psicanálise,, Contagem: 1
# Palavra: flutuação, Contagem: 1
# Palavra: Webcam, Contagem: 1
# Palavra: Cayman?, Contagem: 1
# Palavra: Howls, Contagem: 1
# Palavra: Moving, Contagem: 1
# Palavra: Alysons, Contagem: 2
# Palavra: Michalka, Contagem: 2
# Palavra: Courtney., Contagem: 1
# Palavra: Ostensivamente, Contagem: 1
# Palavra: Rapidamente?, Contagem: 1
# Palavra: favos, Contagem: 1
# Palavra: mel?, Contagem: 1
# Palavra: Animals,, Contagem: 1
# Palavra: Shout, Contagem: 1
# Palavra: 1:20., Contagem: 1
# Palavra: Hermits., Contagem: 1
# Palavra: sincronizadas, Contagem: 1
# Palavra: Britânica,, Contagem: 1
# Palavra: lagoa,, Contagem: 2
# Palavra: Hermits,, Contagem: 1
# Palavra: Honeycombs,, Contagem: 1
# Palavra: Teens,, Contagem: 1
# Palavra: definidos?, Contagem: 1
# Palavra: she-bang., Contagem: 1
# Palavra: Dick?, Contagem: 1
# Palavra: participem,, Contagem: 1
# Palavra: mármore., Contagem: 1
# Palavra: Excursão, Contagem: 1
# Palavra: expressão!, Contagem: 1
# Palavra: Hopeless.There, Contagem: 1
# Palavra: nocautes, Contagem: 1
# Palavra: ocupavam, Contagem: 1
# Palavra: patriótica., Contagem: 1
# Palavra: receberam,, Contagem: 2
# Palavra: criticá-los, Contagem: 1
# Palavra: corrigida, Contagem: 1
# Palavra: versos,, Contagem: 1
# Palavra: velocidade?, Contagem: 1
# Palavra: metros?, Contagem: 1
# Palavra: chocou,, Contagem: 1
# Palavra: bhi, Contagem: 1
# Palavra: kisi, Contagem: 1
# Palavra: ka, Contagem: 1
# Palavra: hai,, Contagem: 1
# Palavra: ise, Contagem: 1
# Palavra: laath, Contagem: 1
# Palavra: mat, Contagem: 2
# Palavra: maro, Contagem: 1
# Palavra: jyaada, Contagem: 1
# Palavra: musalmaan, Contagem: 1
# Palavra: Hindustaan, Contagem: 1
# Palavra: LOC, Contagem: 5
# Palavra: karo, Contagem: 1
# Palavra: ye, Contagem: 1
# Palavra: hukum, Contagem: 1
# Palavra: hai., Contagem: 1
# Palavra: Shobha, Contagem: 1
# Palavra: mostrar?, Contagem: 1
# Palavra: Kargil, Contagem: 1
# Palavra: paquistanesas,, Contagem: 1
# Palavra: fechar., Contagem: 1
# Palavra: LOC., Contagem: 1
# Palavra: soilders,, Contagem: 1
# Palavra: agrupado, Contagem: 1
# Palavra: DUSHMAN2002, Contagem: 1
# Palavra: Kargil,, Contagem: 2
# Palavra: chatas.Mesmo, Contagem: 1
# Palavra: BORDER, Contagem: 1
# Palavra: Bajpai, Contagem: 1
# Palavra: Sanju, Contagem: 1
# Palavra: transitáveis, Contagem: 1
# Palavra: Reunindo, Contagem: 1
# Palavra: Derrota, Contagem: 1
# Palavra: baionetas, Contagem: 1
# Palavra: granadas., Contagem: 1
# Palavra: Supõe, Contagem: 1
# Palavra: atinge., Contagem: 1
# Palavra: pakis, Contagem: 1
# Palavra: infiltrados, Contagem: 1
# Palavra: cruzaram, Contagem: 1
# Palavra: retaliação, Contagem: 1
# Palavra: referentes, Contagem: 1
# Palavra: Kargil.Comentário:, Contagem: 1
# Palavra: Pak., Contagem: 1
# Palavra: homenageados, Contagem: 1
# Palavra: adversidades, Contagem: 1
# Palavra: meteorológicas, Contagem: 1
# Palavra: adversas., Contagem: 1
# Palavra: inexplicadas,, Contagem: 1
# Palavra: NOISE, Contagem: 1
# Palavra: Noise, Contagem: 5
# Palavra: Fenômenos, Contagem: 1
# Palavra: Voz, Contagem: 1
# Palavra: Eletrônica, Contagem: 1
# Palavra: E.V.O, Contagem: 1
# Palavra: ocorrências,, Contagem: 1
# Palavra: corresse, Contagem: 1
# Palavra: EVP,, Contagem: 1
# Palavra: Jonathans,, Contagem: 1
# Palavra: eletrônicos., Contagem: 1
# Palavra: Jonathan?, Contagem: 1
# Palavra: maior?, Contagem: 1
# Palavra: traz,, Contagem: 1
# Palavra: subpar., Contagem: 1
# Palavra: Niall, Contagem: 1
# Palavra: branco;, Contagem: 1
# Palavra: McNeice, Contagem: 1
# Palavra: E.V.P, Contagem: 2
# Palavra: Electronic, Contagem: 2
# Palavra: Phenomenon., Contagem: 1
# Palavra: E.V.P., Contagem: 1
# Palavra: aconteçam.Um, Contagem: 1
# Palavra: questionaram, Contagem: 1
# Palavra: efetivas, Contagem: 1
# Palavra: assombro, Contagem: 1
# Palavra: assombra,, Contagem: 1
# Palavra: cinética, Contagem: 1
# Palavra: gelar, Contagem: 1
# Palavra: além-túmulo., Contagem: 1
# Palavra: flácidas., Contagem: 1
# Palavra: Rivers., Contagem: 1
# Palavra: pêra,, Contagem: 1
# Palavra: drasticamente.Eu, Contagem: 1
# Palavra: cop-out,, Contagem: 1
# Palavra: meio-formados, Contagem: 1
# Palavra: TODOS., Contagem: 1
# Palavra: componente,, Contagem: 1
# Palavra: cliffhangers,, Contagem: 1
# Palavra: estranhamente., Contagem: 1
# Palavra: cefaleia, Contagem: 1
# Palavra: aumentava., Contagem: 1
# Palavra: diligentemente, Contagem: 1
# Palavra: coração-rolha,, Contagem: 1
# Palavra: viewer.While, Contagem: 1
# Palavra: studliest, Contagem: 1
# Palavra: residências, Contagem: 1
# Palavra: maliciosas,, Contagem: 1
# Palavra: mistificada, Contagem: 1
# Palavra: NOISE., Contagem: 1
# Palavra: Keaton;, Contagem: 1
# Palavra: enrugado,, Contagem: 1
# Palavra: EVP, Contagem: 1
# Palavra: Phenomena, Contagem: 1
# Palavra: RUÍDO, Contagem: 1
# Palavra: BRANCO, Contagem: 1
# Palavra: dignam, Contagem: 1
# Palavra: substantivo., Contagem: 1
# Palavra: Wai., Contagem: 1
# Palavra: WKW, Contagem: 1
# Palavra: wuxia;, Contagem: 1
# Palavra: Wongs, Contagem: 2
# Palavra: 2046., Contagem: 1
# Palavra: acessíveis., Contagem: 1
# Palavra: p.o., Contagem: 1
# Palavra: Kongs:, Contagem: 1
# Palavra: femininos;, Contagem: 1
# Palavra: Auteur, Contagem: 1
# Palavra: aplaudido,, Contagem: 1
# Palavra: isoladora, Contagem: 1
# Palavra: categoricamente, Contagem: 1
# Palavra: plebeus, Contagem: 1
# Palavra: vagão., Contagem: 1
# Palavra: acessibilidade, Contagem: 1
# Palavra: aqueceu., Contagem: 1
# Palavra: caligráficos, Contagem: 1
# Palavra: agitar., Contagem: 1
# Palavra: filisteu, Contagem: 1
# Palavra: suey., Contagem: 1
# Palavra: abacaxi., Contagem: 1
# Palavra: California, Contagem: 1
# Palavra: Dreaming, Contagem: 1
# Palavra: abacaxis, Contagem: 1
# Palavra: consumido., Contagem: 1
# Palavra: Fast-forward., Contagem: 1
# Palavra: pick:, Contagem: 1
# Palavra: Jannsen, Contagem: 2
# Palavra: Drivas,, Contagem: 1
# Palavra: parentais, Contagem: 1
# Palavra: incessante,, Contagem: 1
# Palavra: Drivas, Contagem: 3
# Palavra: pente, Contagem: 1
# Palavra: Prima, Contagem: 1
# Palavra: acompanhavam., Contagem: 1
# Palavra: LV, Contagem: 1
# Palavra: ambíguo;, Contagem: 1
# Palavra: gerações,, Contagem: 1
# Palavra: Caesars, Contagem: 1
# Palavra: Edy, Contagem: 1
# Palavra: Vaccarro, Contagem: 1
# Palavra: platonicamente, Contagem: 1
# Palavra: GMR, Contagem: 1
# Palavra: [16], Contagem: 1
# Palavra: Comitê,, Contagem: 1
# Palavra: neo-avante-garde, Contagem: 1
# Palavra: Rickles, Contagem: 2
# Palavra: blackjack, Contagem: 1
# Palavra: CASINO, Contagem: 2
# Palavra: Logans., Contagem: 1
# Palavra: Dias., Contagem: 1
# Palavra: Softly., Contagem: 1
# Palavra: Missys, Contagem: 1
# Palavra: venham., Contagem: 1
# Palavra: Pioneiros, Contagem: 1
# Palavra: ""Pulp, Contagem: 1
# Palavra: Fiction"", Contagem: 1
# Palavra: ""Melhor, Contagem: 1
# Palavra: Filme""., Contagem: 1
# Palavra: ""lento"".", Contagem: 1
# Palavra: não}., Contagem: 1
# Palavra: !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!, Contagem: 1
# Palavra: prende-os, Contagem: 1
# Palavra: interroga-os., Contagem: 1
# Palavra: pensávamos, Contagem: 1
# Palavra: explicado!, Contagem: 1
# Palavra: duólogo, Contagem: 1
# Palavra: COMBAT, Contagem: 1
# Palavra: SHOCK,, Contagem: 1
# Palavra: REQUIEM, Contagem: 1
# Palavra: SONHO, Contagem: 1
# Palavra: BOISE, Contagem: 1
# Palavra: MOI,, Contagem: 1
# Palavra: Dalmers, Contagem: 1
# Palavra: RAVENOUS., Contagem: 1
# Palavra: masoquistas,, Contagem: 1
# Palavra: Damage,, Contagem: 1
# Palavra: skanky, Contagem: 1
# Palavra: ""carne"", Contagem: 1
# Palavra: UGH", Contagem: 1
# Palavra: Cécile, Contagem: 1
# Palavra: Deneuve., Contagem: 1
# Palavra: finalizados., Contagem: 1
# Palavra: Cécile., Contagem: 1
# Palavra: Marrocos., Contagem: 1
# Palavra: construtor,, Contagem: 1
# Palavra: reconstrói, Contagem: 1
# Palavra: Céciles., Contagem: 2
# Palavra: reconciliaram, Contagem: 1
# Palavra: vejam,, Contagem: 2
# Palavra: iraquiano., Contagem: 1
# Palavra: ciles, Contagem: 1
# Palavra: crianÃ§a, Contagem: 1
# Palavra: cÃ, Contagem: 1
# Palavra: islâmica,, Contagem: 1
# Palavra: Retrata, Contagem: 1
# Palavra: extremismo,, Contagem: 1
# Palavra: locale, Contagem: 1
# Palavra: couleur, Contagem: 1
# Palavra: lart, Contagem: 1
# Palavra: pour, Contagem: 1
# Palavra: lart.Deneuve, Contagem: 1
# Palavra: sobrancelha,, Contagem: 1
# Palavra: irradiante,, Contagem: 1
# Palavra: Silenciosa,, Contagem: 2
# Palavra: Mortal, Contagem: 1
# Palavra: agarra., Contagem: 1
# Palavra: aterrorizada,, Contagem: 1
# Palavra: safada., Contagem: 1
# Palavra: espremendo-se, Contagem: 1
# Palavra: sufocando-o, Contagem: 1
# Palavra: Noel;, Contagem: 1
# Palavra: natalino., Contagem: 1
# Palavra: chatice.Eu, Contagem: 1
# Palavra: Maggart,, Contagem: 1
# Palavra: Maggart, Contagem: 1
# Palavra: boquiaberto, Contagem: 2
# Palavra: alucinações!, Contagem: 1
# Palavra: ending.If, Contagem: 1
# Palavra: ""Black, Contagem: 1
# Palavra: Christmas"", Contagem: 1
# Palavra: custo.", Contagem: 1
# Palavra: noel, Contagem: 2
# Palavra: cláusula., Contagem: 1
# Palavra: ACONTECE, Contagem: 1
# Palavra: DAMN., Contagem: 1
# Palavra: MINUTE, Contagem: 1
# Palavra: LONG., Contagem: 1
# Palavra: QUE?, Contagem: 1
# Palavra: rir-me., Contagem: 1
# Palavra: Improvement, Contagem: 1
# Palavra: É?, Contagem: 1
# Palavra: RETHER, Contagem: 1
# Palavra: DOMÉSTICA, Contagem: 1
# Palavra: SESSENTA, Contagem: 1
# Palavra: CAPA, Contagem: 1
# Palavra: NOVAMENTE., Contagem: 1
# Palavra: terça-feira, Contagem: 1
# Palavra: Luis,, Contagem: 1
# Palavra: "Entrando, Contagem: 1
# Palavra: Véspera, Contagem: 1
# Palavra: Horrorizado,, Contagem: 1
# Palavra: Stalling, Contagem: 1
# Palavra: veste-se, Contagem: 1
# Palavra: tocá-lo,, Contagem: 2
# Palavra: ""sexo"", Contagem: 1
# Palavra: binóculos., Contagem: 1
# Palavra: Jolly, Contagem: 1
# Palavra: pegam,, Contagem: 1
# Palavra: machuquem., Contagem: 1
# Palavra: esfaqueá-lo, Contagem: 1
# Palavra: estrangula., Contagem: 1
# Palavra: tira., Contagem: 1
# Palavra: Slay., Contagem: 1
# Palavra: dinheiros, Contagem: 1
# Palavra: qualifica., Contagem: 1
# Palavra: VANITY, Contagem: 1
# Palavra: FAIR, Contagem: 1
# Palavra: Jindabyne, Contagem: 5
# Palavra: relaxamento., Contagem: 1
# Palavra: bruços, Contagem: 1
# Palavra: barranco, Contagem: 1
# Palavra: capturas., Contagem: 1
# Palavra: aborígenes, Contagem: 1
# Palavra: EXPLICIDADE, Contagem: 1
# Palavra: laje, Contagem: 1
# Palavra: Jindabyne:, Contagem: 1
# Palavra: presumida., Contagem: 1
# Palavra: município, Contagem: 1
# Palavra: exploradas, Contagem: 1
# Palavra: instáveis,, Contagem: 1
# Palavra: generalizado, Contagem: 1
# Palavra: simbólicos,, Contagem: 1
# Palavra: NORTHFORK, Contagem: 1
# Palavra: inaudível;, Contagem: 1
# Palavra: outras;, Contagem: 1
# Palavra: garota;, Contagem: 1
# Palavra: paisagem;, Contagem: 1
# Palavra: beiram, Contagem: 1
# Palavra: contamina, Contagem: 1
# Palavra: corno, Contagem: 2
# Palavra: Hollywood-like, Contagem: 1
# Palavra: termina!., Contagem: 1
# Palavra: racista?, Contagem: 1
# Palavra: bizare., Contagem: 1
# Palavra: pescam., Contagem: 1
# Palavra: pescando, Contagem: 1
# Palavra: alegremente,, Contagem: 1
# Palavra: amarram, Contagem: 1
# Palavra: retirá-las, Contagem: 1
# Palavra: deixando-se, Contagem: 1
# Palavra: desfazer?, Contagem: 1
# Palavra: jumble!, Contagem: 1
# Palavra: zinger:, Contagem: 1
# Palavra: descoberta?, Contagem: 1
# Palavra: inacabada., Contagem: 1
# Palavra: carga., Contagem: 1
# Palavra: encorajariam, Contagem: 1
# Palavra: percepção., Contagem: 1
# Palavra: Plan., Contagem: 1
# Palavra: afirmou,, Contagem: 1
# Palavra: garotinho!?, Contagem: 1
# Palavra: Jindabynes, Contagem: 1
# Palavra: categorias.Este, Contagem: 1
# Palavra: patronisingly, Contagem: 1
# Palavra: aborígines, Contagem: 2
# Palavra: alcoólatras;, Contagem: 1
# Palavra: aborígine,, Contagem: 1
# Palavra: truta., Contagem: 1
# Palavra: goodie, Contagem: 1
# Palavra: costal, Contagem: 1
# Palavra: besteiros, Contagem: 1
# Palavra: Conclui, Contagem: 1
# Palavra: Jindabyne,, Contagem: 1
# Palavra: implicação,, Contagem: 1
# Palavra: proclama, Contagem: 1
# Palavra: esclarecidos, Contagem: 1
# Palavra: Governments, Contagem: 1
# Palavra: Finance, Contagem: 1
# Palavra: pródigo, Contagem: 1
# Palavra: pan!, Contagem: 1
# Palavra: incômodos., Contagem: 1
# Palavra: pre-Amelia,, Contagem: 1
# Palavra: Nair, Contagem: 1
# Palavra: nojenta,, Contagem: 1
# Palavra: fossa., Contagem: 1
# Palavra: agarrá-lo, Contagem: 1
# Palavra: interessá-lo, Contagem: 1
# Palavra: estressante., Contagem: 1
# Palavra: interagem., Contagem: 1
# Palavra: chiclete,, Contagem: 2
# Palavra: desvalorizado, Contagem: 1
# Palavra: viria., Contagem: 1
# Palavra: parassonia, Contagem: 1
# Palavra: Scanner, Contagem: 1
# Palavra: Re-Animator., Contagem: 1
# Palavra: Com., Contagem: 1
# Palavra: cereal., Contagem: 1
# Palavra: fediam, Contagem: 1
# Palavra: mildewing., Contagem: 1
# Palavra: religiosamente., Contagem: 1
# Palavra: saxofone,, Contagem: 1
# Palavra: I.T.V,, Contagem: 1
# Palavra: Hawke, Contagem: 2
# Palavra: Dostoiévski., Contagem: 1
# Palavra: marcar,, Contagem: 1
# Palavra: Dostoyevky, Contagem: 1
# Palavra: colo,, Contagem: 1
# Palavra: Sunrise, Contagem: 1
# Palavra: Bites., Contagem: 1
# Palavra: sobrepor, Contagem: 1
# Palavra: DeMatteo,, Contagem: 1
# Palavra: Caan,, Contagem: 1
# Palavra: Staten, Contagem: 1
# Palavra: Heights., Contagem: 1
# Palavra: Jtaime., Contagem: 1
# Palavra: Shia, Contagem: 2
# Palavra: LaBeouf, Contagem: 2
# Palavra: encantador;, Contagem: 1
# Palavra: Ratner, Contagem: 2
# Palavra: reviravolta;, Contagem: 2
# Palavra: 67º, Contagem: 1
# Palavra: Portmans,, Contagem: 1
# Palavra: mistas, Contagem: 1
# Palavra: amêndoas, Contagem: 1
# Palavra: sobraram., Contagem: 1
# Palavra: salvá-lo.Uma, Contagem: 1
# Palavra: Stefan,, Contagem: 1
# Palavra: mal.Este, Contagem: 1
# Palavra: McEnroe,, Contagem: 2
# Palavra: sunnies,, Contagem: 1
# Palavra: decapagem.Durante, Contagem: 1
# Palavra: chato.1, Contagem: 1
# Palavra: concretizadas., Contagem: 1
# Palavra: atraiam., Contagem: 1
# Palavra: Deixou, Contagem: 1
# Palavra: alta-testa, Contagem: 1
# Palavra: salientaram,, Contagem: 2
# Palavra: extirpado, Contagem: 1
# Palavra: escurecido, Contagem: 2
# Palavra: X-rating;, Contagem: 1
# Palavra: criticamente,, Contagem: 1
# Palavra: Dannings., Contagem: 1
# Palavra: anti-lobisomem, Contagem: 1
# Palavra: hmm?, Contagem: 1
# Palavra: anti-licantropo, Contagem: 1
# Palavra: elevá-lo, Contagem: 1
# Palavra: Babel., Contagem: 1
# Palavra: pesam, Contagem: 1
# Palavra: latim., Contagem: 1
# Palavra: Hound., Contagem: 1
# Palavra: youtube.com, Contagem: 1
# Palavra: Babel, Contagem: 1
# Palavra: Bryden, Contagem: 2
# Palavra: DeLane,, Contagem: 2
# Palavra: trabalhou,, Contagem: 1
# Palavra: Bonanza,, Contagem: 1
# Palavra: Flambards,, Contagem: 1
# Palavra: Duquesa, Contagem: 1
# Palavra: Bounder., Contagem: 1
# Palavra: informativos,, Contagem: 1
# Palavra: sibilante., Contagem: 1
# Palavra: Crossroads,, Contagem: 1
# Palavra: pavorosos,, Contagem: 1
# Palavra: O.T.T.,, Contagem: 1
# Palavra: Addicts,, Contagem: 1
# Palavra: Faces., Contagem: 1
# Palavra: despencou,, Contagem: 1
# Palavra: futuras., Contagem: 1
# Palavra: manuscrito,, Contagem: 1
# Palavra: pronúncias, Contagem: 1
# Palavra: JTAIME.,, Contagem: 1
# Palavra: imperfeito,, Contagem: 1
# Palavra: City.Em, Contagem: 1
# Palavra: Jtaimecrei, Contagem: 1
# Palavra: Paris.Neste, Contagem: 1
# Palavra: nascimento.New, Contagem: 1
# Palavra: bairros,, Contagem: 1
# Palavra: Brooklyn,, Contagem: 1
# Palavra: nova-iorquinos, Contagem: 2
# Palavra: razzie, Contagem: 1
# Palavra: melhores.Ratamentos:, Contagem: 1
# Palavra: 10No, Contagem: 1
# Palavra: YORK,, Contagem: 1
# Palavra: ODEIO, Contagem: 1
# Palavra: x-con, Contagem: 1
# Palavra: mensageiro., Contagem: 2
# Palavra: Stefans, Contagem: 1
# Palavra: facilmente.Na, Contagem: 1
# Palavra: Elli,, Contagem: 1
# Palavra: Elli, Contagem: 3
# Palavra: imaginou., Contagem: 1
# Palavra: americanizado., Contagem: 1
# Palavra: Cecilia, Contagem: 1
# Palavra: jugde, Contagem: 1
# Palavra: ""Quest, Contagem: 1
# Palavra: Knights"", Contagem: 1
# Palavra: visualizá-lo, Contagem: 1
# Palavra: Bruckheimer.", Contagem: 1
# Palavra: Paynes, Contagem: 1
# Palavra: ex-oficiais, Contagem: 1
# Palavra: cadetes,, Contagem: 1
# Palavra: Payne., Contagem: 1
# Palavra: consumiria, Contagem: 1
# Palavra: what-ifs, Contagem: 1
# Palavra: suor., Contagem: 1
# Palavra: Aranha,, Contagem: 1
# Palavra: Maguire.O, Contagem: 1
# Palavra: GMorks, Contagem: 1
# Palavra: proclamasse, Contagem: 1
# Palavra: ""nada"", Contagem: 1
# Palavra: GASLIGHT, Contagem: 1
# Palavra: LES, Contagem: 1
# Palavra: DIABOLIQUES, Contagem: 1
# Palavra: 1954;, Contagem: 1
# Palavra: clichê-roed, Contagem: 1
# Palavra: pretendidos., Contagem: 1
# Palavra: conivente,, Contagem: 1
# Palavra: Agutter, Contagem: 1
# Palavra: Moody, Contagem: 1
# Palavra: malfadado,, Contagem: 1
# Palavra: Jaystons,, Contagem: 1
# Palavra: Tomlinson, Contagem: 1
# Palavra: notário, Contagem: 1
# Palavra: maoísta, Contagem: 1
# Palavra: diurna., Contagem: 1
# Palavra: Yuwen,, Contagem: 1
# Palavra: Tian, Contagem: 2
# Palavra: Zhuangzhuang,, Contagem: 1
# Palavra: cênico.Eu, Contagem: 1
# Palavra: insubstancial., Contagem: 2
# Palavra: cafés., Contagem: 1
# Palavra: bagunçadas,, Contagem: 1
# Palavra: Romeu,, Contagem: 2
# Palavra: estás, Contagem: 1
# Palavra: Romeu?, Contagem: 1
# Palavra: punido., Contagem: 1
# Palavra: Mercutio, Contagem: 2
# Palavra: Benvolio, Contagem: 1
# Palavra: espectáculos, Contagem: 1
# Palavra: erráticos, Contagem: 1
# Palavra: Verona,, Contagem: 1
# Palavra: Capuletos, Contagem: 1
# Palavra: Montagues, Contagem: 1
# Palavra: Rycart,, Contagem: 1
# Palavra: Montague,, Contagem: 1
# Palavra: Saire,, Contagem: 1
# Palavra: Capuleto., Contagem: 1
# Palavra: diurnas,, Contagem: 1
# Palavra: estagna, Contagem: 1
# Palavra: medonhos,, Contagem: 1
# Palavra: meias-calças, Contagem: 1
# Palavra: Ryecart, Contagem: 1
# Palavra: Romeo, Contagem: 1
# Palavra: Romeu., Contagem: 1
# Palavra: Saire, Contagem: 1
# Palavra: ingenuidade,, Contagem: 1
# Palavra: Frei, Contagem: 1
# Palavra: gesticula, Contagem: 1
# Palavra: underplaying, Contagem: 1
# Palavra: Tybalt., Contagem: 1
# Palavra: Naismith, Contagem: 1
# Palavra: Hordern,, Contagem: 1
# Palavra: Capuleto, Contagem: 1
# Palavra: adiantado!, Contagem: 1
# Palavra: favorita!, Contagem: 1
# Palavra: choramingar!, Contagem: 1
# Palavra: Revisited,, Contagem: 1
# Palavra: Ivanhoe,, Contagem: 1
# Palavra: puhleasssssee!, Contagem: 1
# Palavra: Clare!, Contagem: 1
# Palavra: Brigadoon, Contagem: 2
# Palavra: vergonhosos., Contagem: 1
# Palavra: contraíam, Contagem: 1
# Palavra: observá-los., Contagem: 1
# Palavra: protegê-las, Contagem: 1
# Palavra: sugar?, Contagem: 1
# Palavra: Nephilim, Contagem: 1
# Palavra: Arcanjo, Contagem: 1
# Palavra: Missy;, Contagem: 1
# Palavra: Gabriel,, Contagem: 2
# Palavra: Danzig, Contagem: 1
# Palavra: pisque, Contagem: 1
# Palavra: Beals., Contagem: 1
# Palavra: Embry,, Contagem: 1
# Palavra: parte.1, Contagem: 1
# Palavra: Nr., Contagem: 5
# Palavra: franjas, Contagem: 1
# Palavra: dimensão,, Contagem: 1
# Palavra: machucam., Contagem: 1
# Palavra: fazer-e-então-lutar-um-monstro,, Contagem: 1
# Palavra: regurgitada, Contagem: 1
# Palavra: auto-envolvidas, Contagem: 1
# Palavra: inclusividade, Contagem: 1
# Palavra: bigorna,, Contagem: 1
# Palavra: ish, Contagem: 1
# Palavra: estropiado,, Contagem: 1
# Palavra: socioeconômica, Contagem: 1
# Palavra: voluntariosa, Contagem: 1
# Palavra: repugnadas, Contagem: 1
# Palavra: rodas?, Contagem: 1
# Palavra: Bilson, Contagem: 1
# Palavra: Jumper., Contagem: 1
# Palavra: questionário, Contagem: 1
# Palavra: Yelchin, Contagem: 1
# Palavra: Thirlby, Contagem: 1
# Palavra: ofendido,, Contagem: 1
# Palavra: relativo., Contagem: 1
# Palavra: REALÇAR., Contagem: 1
# Palavra: tormento, Contagem: 2
# Palavra: masturbatório., Contagem: 1
# Palavra: estavam?, Contagem: 1
# Palavra: demônio?, Contagem: 1
# Palavra: gladiador?, Contagem: 1
# Palavra: supondo., Contagem: 1
# Palavra: bocejos,, Contagem: 1
# Palavra: Paculas, Contagem: 1
# Palavra: eslavo, Contagem: 2
# Palavra: Breuer, Contagem: 2
# Palavra: Nietzsche, Contagem: 3
# Palavra: apagados, Contagem: 1
# Palavra: Nietzsches, Contagem: 1
# Palavra: compreendido,, Contagem: 1
# Palavra: comentário.Eu, Contagem: 1
# Palavra: razões.Sujeito:, Contagem: 1
# Palavra: apaixonadas., Contagem: 1
# Palavra: filósofos, Contagem: 2
# Palavra: pensador., Contagem: 1
# Palavra: tomate., Contagem: 1
# Palavra: tomada.Screenplay:, Contagem: 1
# Palavra: Distrai, Contagem: 1
# Palavra: Alemão!, Contagem: 1
# Palavra: aramaico, Contagem: 1
# Palavra: exagerado.3d,, Contagem: 1
# Palavra: Nietzsche., Contagem: 1
# Palavra: casting.4th,, Contagem: 1
# Palavra: fora.E, Contagem: 1
# Palavra: jaqueta,, Contagem: 1
# Palavra: Yaloms, Contagem: 1
# Palavra: Yalom, Contagem: 1
# Palavra: clínico., Contagem: 2
# Palavra: Salomé, Contagem: 1
# Palavra: encaminhá-los, Contagem: 1
# Palavra: Nietzches,, Contagem: 1
# Palavra: psicanalíticas, Contagem: 1
# Palavra: Viena., Contagem: 1
# Palavra: leu,, Contagem: 1
# Palavra: descreva-o, Contagem: 1
# Palavra: curá-lo,, Contagem: 1
# Palavra: Sotaque,, Contagem: 1
# Palavra: Freud,, Contagem: 1
# Palavra: geniais,, Contagem: 1
# Palavra: Audiência,, Contagem: 1
# Palavra: conceitos., Contagem: 1
# Palavra: eleitorado, Contagem: 1
# Palavra: balançado, Contagem: 1
# Palavra: Conceit, Contagem: 3
# Palavra: unanimemente, Contagem: 1
# Palavra: primeiros-ministros, Contagem: 1
# Palavra: MI5,, Contagem: 1
# Palavra: sindicais,, Contagem: 1
# Palavra: consumada, Contagem: 1
# Palavra: Conceição, Contagem: 2
# Palavra: Cortar, Contagem: 1
# Palavra: reacionárias, Contagem: 1
# Palavra: procurariam, Contagem: 1
# Palavra: anti-Thatcher, Contagem: 1
# Palavra: louvores., Contagem: 1
# Palavra: influente,, Contagem: 1
# Palavra: McInallys, Contagem: 1
# Palavra: Je, Contagem: 2
# Palavra: Taime,, Contagem: 1
# Palavra: bairros., Contagem: 1
# Palavra: correspondido,, Contagem: 1
# Palavra: resgatáveis,, Contagem: 1
# Palavra: Christies, Contagem: 1
# Palavra: evocava, Contagem: 1
# Palavra: favorável,, Contagem: 1
# Palavra: auto-intitulada., Contagem: 1
# Palavra: Taime, Contagem: 1
# Palavra: Sipsey, Contagem: 1
# Palavra: Natal.Dê-me, Contagem: 1
# Palavra: 1951., Contagem: 1
# Palavra: Scrooged,, Contagem: 1
# Palavra: compartilhamento, Contagem: 1
# Palavra: doação, Contagem: 2
# Palavra: Yup, Contagem: 1
# Palavra: Moyer,, Contagem: 1
# Palavra: ragistas, Contagem: 1
# Palavra: trablistas, Contagem: 1
# Palavra: juramentos, Contagem: 1
# Palavra: hebraicos?, Contagem: 1
# Palavra: dearz,, Contagem: 1
# Palavra: I´M, Contagem: 1
# Palavra: NOT, Contagem: 1
# Palavra: RAPPAPORT, Contagem: 1
# Palavra: irregulares., Contagem: 1
# Palavra: Herren, Contagem: 1
# Palavra: Vidals, Contagem: 1
# Palavra: Myra,, Contagem: 2
# Palavra: icônica,, Contagem: 1
# Palavra: reencontrei, Contagem: 1
# Palavra: Myra, Contagem: 3
# Palavra: Sexploitation, Contagem: 1
# Palavra: informar,, Contagem: 1
# Palavra: descansou., Contagem: 1
# Palavra: ProducerRobert, Contagem: 1
# Palavra: Fryer, Contagem: 1
# Palavra: Sarne, Contagem: 4
# Palavra: boletins, Contagem: 2
# Palavra: parte.E, Contagem: 1
# Palavra: Vidal,, Contagem: 1
# Palavra: Loner,, Contagem: 1
# Palavra: ex-Cowboy, Contagem: 1
# Palavra: oversexed, Contagem: 1
# Palavra: Backus,, Contagem: 1
# Palavra: Médicos,, Contagem: 1
# ...
# Palavra: abrigavam, Contagem: 1
# Palavra: balsas., Contagem: 1
# Palavra: machos., Contagem: 1
# Palavra: barco?, Contagem: 1
# Palavra: Hugh,, Contagem: 1
# Palavra: Tecnologia, Contagem: 1
# Palavra: devolveu, Contagem: 1
# Palavra: agravamento, Contagem: 1
# Palavra: continuaram., Contagem: 1
# Palavra: Meryl,, Contagem: 1
# Palavra: eremita., Contagem: 1
# Palavra: auto-centrados, Contagem: 1
# Palavra: sair;, Contagem: 1
# Palavra: respeitavelmente, Contagem: 1
# Palavra: espertinho,, Contagem: 1
# Palavra: IMDb.The, Contagem: 1
# Palavra: liso,, Contagem: 1
# Palavra: temidos, Contagem: 1
# Palavra: Boggins,, Contagem: 1
# Palavra: Bunce, Contagem: 1
# Palavra: vai.Eu, Contagem: 1
# Palavra: críticas.Bem,, Contagem: 1
# Palavra: Matilda, Contagem: 1
# Palavra: presumidas, Contagem: 1
# Palavra: simpatize, Contagem: 1
# Palavra: médiuns., Contagem: 1
# Palavra: conversam;, Contagem: 1
# Palavra: redemoinhos, Contagem: 1
# Palavra: ficar!, Contagem: 1
# Palavra: erótico?, Contagem: 1
# Palavra: Bo,, Contagem: 1
# Palavra: atipicamente,, Contagem: 1
# Palavra: fotografou;, Contagem: 1
# Palavra: Hooten, Contagem: 3
# Palavra: Bos:, Contagem: 1
# Palavra: implacabilidade., Contagem: 1
# Palavra: maluco?, Contagem: 1
# Palavra: filme.Também, Contagem: 1
# Palavra: non-eventos, Contagem: 1
# Palavra: incorre, Contagem: 1
# Palavra: PÚBLICO, Contagem: 1
# Palavra: [1931]!, Contagem: 1
# Palavra: avidez, Contagem: 1
# Palavra: lidando., Contagem: 1
# Palavra: documentada, Contagem: 1
# Palavra: cúmplice., Contagem: 1
# Palavra: RACE., Contagem: 1
# Palavra: Juntar, Contagem: 1
# Palavra: Treacher, Contagem: 2
# Palavra: Wodehouses, Contagem: 1
# Palavra: atropelou, Contagem: 1
# Palavra: Bertie, Contagem: 2
# Palavra: Wooster,, Contagem: 1
# Palavra: Jeeves,, Contagem: 1
# Palavra: manobristas., Contagem: 1
# Palavra: wodehousiano., Contagem: 1
# Palavra: PASSOA, Contagem: 1
# Palavra: VIVE,, Contagem: 1
# Palavra: JEEVES, Contagem: 1
# Palavra: Jeeves, Contagem: 1
# Palavra: goof., Contagem: 2
# Palavra: ousadas, Contagem: 1
# Palavra: aplaudo., Contagem: 1
# Palavra: Influence., Contagem: 1
# Palavra: devastadoramente, Contagem: 1
# Palavra: conseguiria., Contagem: 1
# Palavra: perturbadas,, Contagem: 1
# Palavra: inibida, Contagem: 1
# Palavra: desinibida, Contagem: 1
# Palavra: público.Novidades, Contagem: 1
# Palavra: altamente,, Contagem: 1
# Palavra: solipsismo, Contagem: 1
# Palavra: tortuosamente, Contagem: 1
# Palavra: empregasse, Contagem: 1
# Palavra: autodisciplina, Contagem: 1
# Palavra: anti-establishment?, Contagem: 1
# Palavra: improvisados., Contagem: 1
# Palavra: convertido., Contagem: 1
# Palavra: Influence, Contagem: 1
# Palavra: maldita., Contagem: 1
# Palavra: comprometida,, Contagem: 2
# Palavra: recebê-la, Contagem: 1
# Palavra: convidaria, Contagem: 1
# Palavra: frágil?, Contagem: 1
# Palavra: espaguete?, Contagem: 1
# Palavra: força-a, Contagem: 1
# Palavra: instável;, Contagem: 1
# Palavra: melhorá-la, Contagem: 1
# Palavra: examiná-las, Contagem: 1
# Palavra: redimiu;, Contagem: 1
# Palavra: gesticulations, Contagem: 1
# Palavra: fenomenais., Contagem: 1
# Palavra: Mabels,, Contagem: 1
# Palavra: Longhetti., Contagem: 1
# Palavra: Influência,, Contagem: 1
# Palavra: gaveta., Contagem: 1
# Palavra: roqueiro., Contagem: 1
# Palavra: apoiá-la, Contagem: 1
# Palavra: apoiá-la., Contagem: 1
# Palavra: confortá-la,, Contagem: 1
# Palavra: enfrentá-la, Contagem: 1
# Palavra: defendê-la., Contagem: 1
# Palavra: menstruação., Contagem: 1
# Palavra: HistóriaEste, Contagem: 1
# Palavra: catástrofe;, Contagem: 1
# Palavra: soldas, Contagem: 1
# Palavra: Cleópatra, Contagem: 3
# Palavra: macedônia,, Contagem: 1
# Palavra: obtidos, Contagem: 1
# Palavra: descrito., Contagem: 1
# Palavra: valorização, Contagem: 1
# Palavra: divertir!, Contagem: 1
# Palavra: parricídio, Contagem: 1
# Palavra: junção., Contagem: 1
# Palavra: Celopatra, Contagem: 1
# Palavra: novata,, Contagem: 1
# Palavra: Varela, Contagem: 1
# Palavra: Thimothy, Contagem: 1
# Palavra: parricídio,, Contagem: 1
# Palavra: Marc-Antoine,, Contagem: 1
# Palavra: luxuosa:, Contagem: 1
# Palavra: decorados, Contagem: 1
# Palavra: esplêndidos., Contagem: 1
# Palavra: alimentava, Contagem: 1
# Palavra: povo!?!?, Contagem: 1
# Palavra: justificá-la, Contagem: 1
# Palavra: descrição.Cleopatra, Contagem: 1
# Palavra: baseavam-se, Contagem: 1
# Palavra: autopreservação!, Contagem: 1
# Palavra: Ceasar, Contagem: 1
# Palavra: Anthony., Contagem: 1
# Palavra: Otaviano, Contagem: 1
# Palavra: seduzido., Contagem: 1
# Palavra: Mayas., Contagem: 1
# Palavra: iludir., Contagem: 1
# Palavra: Conhecemos, Contagem: 1
# Palavra: Creely,, Contagem: 1
# Palavra: Mapples., Contagem: 1
# Palavra: abalaria, Contagem: 1
# Palavra: Acabe, Contagem: 1
# Palavra: Código., Contagem: 1
# Palavra: estremeceu., Contagem: 1
# Palavra: Ahabs, Contagem: 1
# Palavra: caçou, Contagem: 1
# Palavra: Melvilles,, Contagem: 1
# Palavra: Ahabs,, Contagem: 1
# Palavra: Pequod,, Contagem: 1
# Palavra: Queequeg,, Contagem: 1
# Palavra: arpoador, Contagem: 1
# Palavra: Stubbs, Contagem: 1
# Palavra: pretendida,, Contagem: 1
# Palavra: reescritura, Contagem: 1
# Palavra: Harbor,, Contagem: 1
# Palavra: ferver,, Contagem: 1
# Palavra: Makin, Contagem: 2
# Palavra: 1943, Contagem: 1
# Palavra: Balderdash!, Contagem: 1
# Palavra: lamacentas, Contagem: 1
# Palavra: Japs, Contagem: 1
# Palavra: Sessenta, Contagem: 1
# Palavra: desorientados,, Contagem: 1
# Palavra: renderem,, Contagem: 1
# Palavra: abandonados!, Contagem: 1
# Palavra: mandíbula,, Contagem: 1
# Palavra: Thorwald, Contagem: 1
# Palavra: Landon,, Contagem: 1
# Palavra: Milburn, Contagem: 1
# Palavra: Levene,, Contagem: 1
# Palavra: zombadores, Contagem: 1
# Palavra: Reefer, Contagem: 1
# Palavra: Madness, Contagem: 1
# Palavra: Merlot, Contagem: 1
# Palavra: moderados., Contagem: 1
# Palavra: intelectualizaram, Contagem: 1
# Palavra: Danl, Contagem: 1
# Palavra: matinas, Contagem: 1
# Palavra: tagarelice,, Contagem: 1
# Palavra: latindo,, Contagem: 1
# Palavra: peidando,, Contagem: 1
# Palavra: entontecer, Contagem: 1
# Palavra: Oz.IMDb, Contagem: 1
# Palavra: herogathers, Contagem: 1
# Palavra: colocarmos, Contagem: 1
# Palavra: quartel, Contagem: 1
# Palavra: surpresas.Uma, Contagem: 1
# Palavra: cibernético., Contagem: 1
# Palavra: enchiam, Contagem: 1
# Palavra: whippersnappers., Contagem: 1
# Palavra: entraram., Contagem: 1
# Palavra: esbanjasse, Contagem: 1
# Palavra: copiosas., Contagem: 1
# Palavra: Sam.Para, Contagem: 1
# Palavra: pulverizar, Contagem: 1
# Palavra: atribuí, Contagem: 1
# Palavra: transitou, Contagem: 1
# Palavra: assistissem., Contagem: 1
# Palavra: Realisticamente, Contagem: 1
# Palavra: rasos?, Contagem: 1
# Palavra: cardumes., Contagem: 1
# Palavra: duplas,, Contagem: 1
# Palavra: Fronteira., Contagem: 1
# Palavra: 1982?, Contagem: 1
# Palavra: Bunchs,, Contagem: 1
# Palavra: Walon, Contagem: 1
# Palavra: semáforo, Contagem: 1
# Palavra: Oates,, Contagem: 1
# Palavra: Perrine,, Contagem: 1
# Palavra: conspícuo,, Contagem: 1
# Palavra: patrulheiro, Contagem: 1
# Palavra: Nicholsons, Contagem: 1
# Palavra: reescrevessem, Contagem: 1
# Palavra: castrado, Contagem: 1
# Palavra: proeminentemente, Contagem: 1
# Palavra: continuidade:, Contagem: 1
# Palavra: Perrines, Contagem: 1
# Palavra: exponencial., Contagem: 1
# Palavra: Ry, Contagem: 1
# Palavra: Cooders, Contagem: 1
# Palavra: Borderline,, Contagem: 1
# Palavra: economicamente., Contagem: 1
# Palavra: Oates, Contagem: 1
# Palavra: interconectadas,, Contagem: 1
# Palavra: vizinha,, Contagem: 1
# Palavra: áridas., Contagem: 1
# Palavra: demais.A, Contagem: 1
# Palavra: guarda-sol, Contagem: 1
# Palavra: nevasca,, Contagem: 1
# Palavra: Descent, Contagem: 2
# Palavra: agredida, Contagem: 1
# Palavra: Sub-par, Contagem: 1
# Palavra: mendigar, Contagem: 1
# Palavra: sogras, Contagem: 1
# Palavra: jangada,, Contagem: 1
# Palavra: advogado-namorado,, Contagem: 1
# Palavra: landfall., Contagem: 1
# Palavra: salva-vidas., Contagem: 1
# Palavra: rocha., Contagem: 1
# Palavra: convincente.Este, Contagem: 1
# Palavra: oscila., Contagem: 1
# Palavra: top,, Contagem: 1
# Palavra: OITO, Contagem: 1
# Palavra: pipas, Contagem: 1
# Palavra: tatuam, Contagem: 1
# Palavra: podridão!, Contagem: 1
# Palavra: contra-ataca., Contagem: 1
# Palavra: vigilantismo., Contagem: 1
# Palavra: anula, Contagem: 1
# Palavra: judicial., Contagem: 1
# Palavra: Accused"", Contagem: 1
# Palavra: ""Descida"", Contagem: 1
# Palavra: acusador?, Contagem: 1
# Palavra: Não!!!", Contagem: 1
# Palavra: atolados, Contagem: 1
# Palavra: Do-Do., Contagem: 1
# Palavra: Wackyland,, Contagem: 1
# Palavra: Do-Do, Contagem: 2
# Palavra: Freleng., Contagem: 1
# Palavra: Freleng, Contagem: 1
# Palavra: Clampetts., Contagem: 1
# Palavra: colorização, Contagem: 1
# Palavra: 30º, Contagem: 1
# Palavra: Saddles,, Contagem: 1
# Palavra: piloto?, Contagem: 1
# Palavra: Flat, Contagem: 1
# Palavra: sacou., Contagem: 1
# Palavra: ​​escritores, Contagem: 1
# Palavra: ensinasse, Contagem: 1
# Palavra: prescrever, Contagem: 1
# Palavra: mim""., Contagem: 1
# Palavra: sentarem-se, Contagem: 1
# Palavra: psicopata?, Contagem: 1
# Palavra: dele.", Contagem: 1
# Palavra: piedosa, Contagem: 1
# Palavra: semanal,, Contagem: 1
# Palavra: pretende-se, Contagem: 1
# Palavra: Cleavon, Contagem: 1
# Palavra: transparece, Contagem: 1
# Palavra: Duryea,, Contagem: 1
# Palavra: lookirs, Contagem: 1
# Palavra: casado;, Contagem: 1
# Palavra: Woolrich, Contagem: 1
# Palavra: Stones,, Contagem: 2
# Palavra: hippie,, Contagem: 1
# Palavra: Eurotrash,, Contagem: 1
# Palavra: polemista, Contagem: 1
# Palavra: maoísta., Contagem: 1
# Palavra: ismos, Contagem: 1
# Palavra: destruir,, Contagem: 1
# Palavra: pergunte-se:, Contagem: 1
# Palavra: locutores, Contagem: 1
# Palavra: diatribes, Contagem: 1
# Palavra: caso?, Contagem: 1
# Palavra: Jean-Luc!, Contagem: 1
# Palavra: Stones:, Contagem: 1
# Palavra: eclipsando, Contagem: 1
# Palavra: Copping-out,, Contagem: 1
# Palavra: ​​afirmem, Contagem: 1
# Palavra: Americain,, Contagem: 1
# Palavra: Mepris!, Contagem: 1
# Palavra: Devil., Contagem: 1
# Palavra: Olympic, Contagem: 1
# Palavra: Escolhi, Contagem: 1
# Palavra: animado.Eu, Contagem: 1
# Palavra: aborrecido.É, Contagem: 1
# Palavra: reduz-me, Contagem: 1
# Palavra: desespero;, Contagem: 1
# Palavra: Godards;, Contagem: 1
# Palavra: Devil,, Contagem: 1
# Palavra: testemunhamos,, Contagem: 1
# Palavra: acordes,, Contagem: 1
# Palavra: Zeppelins, Contagem: 1
# Palavra: ThankyouLed, Contagem: 1
# Palavra: declama, Contagem: 1
# Palavra: verso., Contagem: 1
# Palavra: Panteras, Contagem: 1
# Palavra: pornografia;, Contagem: 1
# Palavra: desmentia, Contagem: 1
# Palavra: Times!, Contagem: 1
# Palavra: Nonos,, Contagem: 1
# Palavra: caricodamore., Contagem: 1
# Palavra: comi, Contagem: 1
# Palavra: pellet, Contagem: 1
# Palavra: Trojan, Contagem: 2
# Palavra: preservativos, Contagem: 1
# Palavra: homoerotismo., Contagem: 1
# Palavra: protuberante, Contagem: 1
# Palavra: limão,, Contagem: 1
# Palavra: pêssego, Contagem: 1
# Palavra: queen!, Contagem: 1
# Palavra: conversam., Contagem: 1
# Palavra: transmitir?, Contagem: 1
# Palavra: misserably, Contagem: 1
# Palavra: Phht, Contagem: 1
# Palavra: ICE-T, Contagem: 1
# Palavra: Colina, Contagem: 1
# Palavra: Spaz-15, Contagem: 1
# Palavra: SHOTGUN, Contagem: 1
# Palavra: shells, Contagem: 1
# Palavra: Espingardas, Contagem: 1
# Palavra: jardas., Contagem: 1
# Palavra: reflexo., Contagem: 1
# Palavra: atrapalharia, Contagem: 1
# Palavra: actionscenes, Contagem: 1
# Palavra: botching-los., Contagem: 1
# Palavra: permite,, Contagem: 1
# Palavra: estuprados,, Contagem: 1
# Palavra: assistir.3.2, Contagem: 1
# Palavra: Deerfield, Contagem: 1
# Palavra: Marthe, Contagem: 3
# Palavra: Shut?, Contagem: 1
# Palavra: Corra,, Contagem: 1
# Palavra: Deerfield., Contagem: 1
# Palavra: Kllers, Contagem: 1
# Palavra: MSFT3000, Contagem: 1
# Palavra: reparável., Contagem: 1
# Palavra: FALAM!, Contagem: 1
# Palavra: desenvolvido!, Contagem: 1
# Palavra: "Fiz, Contagem: 1
# Palavra: Anny, Contagem: 1
# Palavra: Duperrey, Contagem: 1
# Palavra: 70/80., Contagem: 1
# Palavra: absolutos, Contagem: 1
# Palavra: deselegantes, Contagem: 1
# Palavra: ""Love, Contagem: 1
# Palavra: decepcionado.", Contagem: 1
# Palavra: regressivo,, Contagem: 1
# Palavra: antiestablishment, Contagem: 1
# Palavra: anti-civilização,, Contagem: 1
# Palavra: inaudíveis, Contagem: 1
# Palavra: enfurecedoramente, Contagem: 1
# Palavra: maniqueístas, Contagem: 1
# Palavra: apelativamente, Contagem: 1
# Palavra: simplistas:, Contagem: 1
# Palavra: trôpegos, Contagem: 1
# Palavra: predatórios, Contagem: 1
# Palavra: bereantes, Contagem: 1
# Palavra: histeria-parte, Contagem: 1
# Palavra: insincera, Contagem: 1
# Palavra: desinteressada!, Contagem: 1
# Palavra: HEDGEHOG, Contagem: 1
# Palavra: molhos, Contagem: 1
# Palavra: sub-dogma., Contagem: 1
# Palavra: Yawneroony!, Contagem: 1
# Palavra: não-Hollywood,, Contagem: 1
# Palavra: atordoar, Contagem: 1
# Palavra: Perdoe-me,, Contagem: 1
# Palavra: Dawson,, Contagem: 1
# Palavra: NC17., Contagem: 1
# Palavra: Rosario,, Contagem: 1
# Palavra: Digital, Contagem: 1
# Palavra: Whishaw, Contagem: 2
# Palavra: segredos,, Contagem: 1
# Palavra: Whishaw,, Contagem: 1
# Palavra: mergulham, Contagem: 1
# Palavra: traumatizados, Contagem: 1
# Palavra: intrometer,, Contagem: 1
# Palavra: Rotheroe, Contagem: 1
# Palavra: recompensador., Contagem: 1
# Palavra: satisfaz., Contagem: 1
# Palavra: arderam, Contagem: 1
# Palavra: coisa.Eu, Contagem: 1
# Palavra: conecto, Contagem: 1
# Palavra: Champs, Contagem: 1
# Palavra: Elysee, Contagem: 1
# Palavra: Arco, Contagem: 1
# Palavra: Triunfo, Contagem: 1
# Palavra: Piers, Contagem: 1
# Palavra: Read,, Contagem: 1
# Palavra: Odile, Contagem: 1
# Palavra: Vernois, Contagem: 1
# Palavra: co-estrela,, Contagem: 1
# Palavra: castrados., Contagem: 1
# Palavra: peteca, Contagem: 1
# Palavra: badminton., Contagem: 1
# Palavra: ex-professora!, Contagem: 1
# Palavra: porque?!, Contagem: 1
# Palavra: assistência,, Contagem: 1
# Palavra: 3-D., Contagem: 1
# Palavra: Macchio,, Contagem: 1
# Palavra: Professores, Contagem: 1
# Palavra: Hirshs, Contagem: 1
# Palavra: Derns., Contagem: 1
# Palavra: PROBLEM, Contagem: 1
# Palavra: Grandpas., Contagem: 1
# Palavra: EARTH., Contagem: 1
# Palavra: CHICKEN, Contagem: 1
# Palavra: RUN, Contagem: 1
# Palavra: vez.1, Contagem: 1
# Palavra: dou., Contagem: 1
# Palavra: infernos, Contagem: 1
# Palavra: Folgadamente, Contagem: 1
# Palavra: Dugan, Contagem: 1
# Palavra: ativar, Contagem: 1
# Palavra: adotar,, Contagem: 1
# Palavra: adotá-lo, Contagem: 1
# Palavra: notados., Contagem: 1
# Palavra: Blonde,, Contagem: 1
# Palavra: Andar, Contagem: 1
# Palavra: Falar,, Contagem: 1
# Palavra: Maravilhoso,, Contagem: 1
# Palavra: classificaram., Contagem: 1
# Palavra: Paranoia, Contagem: 1
# Palavra: agrada,, Contagem: 1
# Palavra: nix, Contagem: 1
# Palavra: juiz?, Contagem: 1
# Palavra: inusitados, Contagem: 1
# Palavra: produtores.Voto:, Contagem: 1
# Palavra: "Ah, Contagem: 1
# Palavra: yez,, Contagem: 1
# Palavra: Yeti, Contagem: 6
# Palavra: fósforos,, Contagem: 1
# Palavra: queimaram?, Contagem: 1
# Palavra: vegan, Contagem: 1
# Palavra: hah, Contagem: 1
# Palavra: acelerador?, Contagem: 1
# Palavra: yeti, Contagem: 1
# Palavra: sangrava., Contagem: 1
# Palavra: yeti,, Contagem: 1
# Palavra: revólver,, Contagem: 1
# Palavra: disparou., Contagem: 1
# Palavra: Marinaro, Contagem: 1
# Palavra: roedor,, Contagem: 2
# Palavra: lagomorfo., Contagem: 1
# Palavra: ""Tem, Contagem: 1
# Palavra: Yeti:, Contagem: 3
# Palavra: trovões,, Contagem: 1
# Palavra: Himalaia., Contagem: 1
# Palavra: chegue., Contagem: 1
# Palavra: Preso,, Contagem: 1
# Palavra: apelidando-as, Contagem: 1
# Palavra: Festa, Contagem: 1
# Palavra: Besta!, Contagem: 1
# Palavra: Ziller,, Contagem: 1
# Palavra: procurá-los?, Contagem: 1
# Palavra: alinhá-lo, Contagem: 1
# Palavra: Feasts, Contagem: 1
# Palavra: pula-pula., Contagem: 1
# Palavra: Raksha:, Contagem: 1
# Palavra: Raksha, Contagem: 1
# Palavra: Sânscrito, Contagem: 1
# Palavra: Tibetano,, Contagem: 1
# Palavra: Himalaia, Contagem: 1
# Palavra: ajudou.Yeti:, Contagem: 1
# Palavra: ​​outra, Contagem: 1
# Palavra: Sc-Fi, Contagem: 1
# Palavra: considerariam, Contagem: 1
# Palavra: casualmente., Contagem: 1
# Palavra: pegando-os, Contagem: 1
# Palavra: Stockholm, Contagem: 1
# Palavra: Decepção, Contagem: 1
# Palavra: clássicos!, Contagem: 1
# Palavra: estuprada:, Contagem: 1
# Palavra: intensidade!, Contagem: 1
# Palavra: Irreversível,, Contagem: 1
# Palavra: americano-canadense, Contagem: 1
# Palavra: Hardgore, Contagem: 2
# Palavra: Fedor, Contagem: 1
# Palavra: búzio., Contagem: 1
# Palavra: caronista,, Contagem: 1
# Palavra: definham, Contagem: 1
# Palavra: pensa:, Contagem: 1
# Palavra: “Oh, Contagem: 1
# Palavra: ilegalmente,, Contagem: 1
# Palavra: baixado,, Contagem: 1

# %%
total_word_count = word_counts.map(lambda x: x[1]).reduce(reduce_function)

# %%
print("João Victor, RU: 4538676, E o total de palavras nos textos negativos:", total_word_count)
# Out:
# João Victor, RU: 4538676, E o total de palavras nos textos negativos: 2415179

# %% [markdown]
# # Questão 2:
#
# Nesta questão, você irá calcular a diferença no número total de palavras entre textos negativos em português e inglês.
#
# ### Objetivo:
# - Contar as palavras em cada idioma (colunas 'text_pt' e 'text_en') para entradas onde o sentimento ('sentiment') é 'neg'.
# - Subtrair o total de palavras em inglês do total em português.

# %% [markdown]
# ## Criar funções de MAP:
# - Criar função para mapear o "sentiment" como chave de uma tupla principal e como valor uma outra tupla com a soma das palavras de cada idioma como valor.
#
# A função map irá transformar cada linha do dataframe em uma tupla (chave-valor), onde:
# - Chave: coluna 'sentiment'
# - Valor: Nova tupla com:
#   - Elemento 0: soma das palavras da coluna 'text_en'
#   - Elemento 1: soma das palavras da coluna 'text_pt'
#
# OU
# - Chave: coluna 'sentiment'
# - Valor: (soma das palavras da coluna 'text_pt') - (soma das palavras da coluna 'text_en')
#
#
# Para contar as palavras deve-se primeiro separar os textos em uma lista de palavras para então descobrir o tamanho desta lista.
# Dicas:
#
# 1. Use o método .split() e não .split(" ") de string para separar as palavras em uma lista ou use a função split(coluna de texto, regex) do pyspark com o regex igual à "[ ]+" ou "\s+"
# 2. Use len() para descobrir o tamanho da lista de palavras.

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("CountingWords").getOrCreate()

# %%
df = spark.read.csv("/content/imdb-reviews-pt-br.csv", header=True, inferSchema=True)

# %%
negative_df = df.filter(df.sentiment == "neg")

# %%
def count_words(text):
    return len(text.split())

# %%
def map_function(row):
    sentiment = row.sentiment
    pt_count = count_words(row.text_pt)
    en_count = count_words(row.text_en)
    return (sentiment, (pt_count, en_count))

# %% [markdown]
# ## Cria funções de REDUCE:
#
# - Criar função de reduce para somar o numero de palavras de cada texto português e inglês por "sentiment" (dependerá de como você optou por fazer sua função map2).
#
# A função reduce irá somar os valores das quantidades de palavras agrupados por chave ('sentiment').

# %%
def reduce_function(x, y):
    pt_count = x[0] + y[0]
    en_count = x[1] + y[1]
    return (pt_count, en_count)

# %% [markdown]
# ## Aplicação do map/reduce e visualização do resultado
#
# 1. Aplicar o map/reduce no seu dataframe spark e realizar o collect() ao final
# 2. Selecionar os dados referentes aos textos negativos para realizar a subtração.
# 3. Realizar a subtração das contagens de palavras dos textos negativos para obter o resultado final

# %%
word_counts = negative_df.rdd.map(map_function).reduceByKey(reduce_function)

# %%
result = word_counts.collect()

# %%
for sentiment, (pt_count, en_count) in result:
    print(f"RU 45386760 e o Sentimento é: {sentiment}, e as Contagens de Palavras em Português e Inglês são: {pt_count} - {en_count}")
# Out:
# RU 45386760 e o Sentimento é: neg, e as Contagens de Palavras em Português e Inglês são: 2415179 - 2399150

# %%
pt_count = next((pt_count for sentiment, (pt_count, en_count) in result if sentiment == "neg"), 0)
en_count = next((en_count for sentiment, (pt_count, en_count) in result if sentiment == "neg"), 0)

# %%
difference = pt_count - en_count

# %%
from pyspark.sql import SparkSession

# Inicializar a sessão Spark
spark = SparkSession.builder.appName("WordCountDifference").getOrCreate()

# Ler o arquivo CSV como um DataFrame
df = spark.read.csv("/content/imdb-reviews-pt-br.csv", header=True, inferSchema=True)

# Filtrar linhas com sentimento negativo
negative_df = df.filter(df.sentiment == "neg")

# Função de MAP para contar palavras
def map_function(row):
    sentiment = row["sentiment"]
    text = row["text_pt" if sentiment == "neg" else "text_en"]
    words = text.split()
    return (sentiment, len(words))

# Função de REDUCE para somar contagens de palavras
def reduce_function(count1, count2):
    return count1 + count2

# Aplicar a função de MAP e REDUCE
word_counts = negative_df.rdd.map(map_function).reduceByKey(reduce_function)

# Filtrar contagem de palavras para textos em português e inglês
pt_count = word_counts.filter(lambda x: x[0] == "neg").map(lambda x: x[1]).collect()[0]
en_count = word_counts.filter(lambda x: x[0] == "neg_en").map(lambda x: x[1]).collect()

# Verificar se há contagem de palavras em inglês e calcular a diferença
difference = pt_count - en_count[0] if en_count else pt_count

# Imprimir o resultado da diferença
print("João Victor, RU: 4538676, Diferença no total de palavras entre português e inglês:", difference)
# Out:
# João Victor, RU: 4538676, Diferença no total de palavras entre português e inglês: 2415179
